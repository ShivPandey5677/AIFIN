# %%
# Out:
# Requirement already satisfied: newspaper3k in c:\users\asus\appdata\roaming\python\python311\site-packages (0.2.8)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in c:\users\asus\appdata\roaming\python\python311\site-packages (from newspaper3k) (4.12.3)
# Requirement already satisfied: Pillow>=3.3.0 in c:\python311\lib\site-packages (from newspaper3k) (10.3.0)
# Requirement already satisfied: PyYAML>=3.11 in c:\python311\lib\site-packages (from newspaper3k) (6.0.2)
# Requirement already satisfied: cssselect>=0.9.2 in c:\users\asus\appdata\roaming\python\python311\site-packages (from newspaper3k) (1.2.0)
# Requirement already satisfied: lxml>=3.6.0 in c:\users\asus\appdata\roaming\python\python311\site-packages (from newspaper3k) (5.2.2)
# Requirement already satisfied: nltk>=3.2.1 in c:\python311\lib\site-packages (from newspaper3k) (3.9.1)
# Requirement already satisfied: requests>=2.10.0 in c:\users\asus\appdata\roaming\python\python311\site-packages (from newspaper3k) (2.32.1)
# Requirement already satisfied: feedparser>=5.2.1 in c:\users\asus\appdata\roaming\python\python311\site-packages (from newspaper3k) (6.0.11)
# Requirement already satisfied: tldextract>=2.0.1 in c:\users\asus\appdata\roaming\python\python311\site-packages (from newspaper3k) (5.1.3)
# Requirement already satisfied: feedfinder2>=0.0.4 in c:\users\asus\appdata\roaming\python\python311\site-packages (from newspaper3k) (0.0.4)
# Requirement already satisfied: jieba3k>=0.35.1 in c:\users\asus\appdata\roaming\python\python311\site-packages (from newspaper3k) (0.35.1)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\asus\appdata\roaming\python\python311\site-packages (from newspaper3k) (2.9.0.post0)
# Requirement already satisfied: tinysegmenter==0.3 in c:\users\asus\appdata\roaming\python\python311\site-packages (from newspaper3k) (0.3)
# Requirement already satisfied: soupsieve>1.2 in c:\python311\lib\site-packages (from beautifulsoup4>=4.4.1->newspaper3k) (2.5)
# Requirement already satisfied: six in c:\users\asus\appdata\roaming\python\python311\site-packages (from feedfinder2>=0.0.4->newspaper3k) (1.16.0)
# Requirement already satisfied: sgmllib3k in c:\users\asus\appdata\roaming\python\python311\site-packages (from feedparser>=5.2.1->newspaper3k) (1.0.0)
# Requirement already satisfied: click in c:\python311\lib\site-packages (from nltk>=3.2.1->newspaper3k) (8.1.7)
# Requirement already satisfied: joblib in c:\python311\lib\site-packages (from nltk>=3.2.1->newspaper3k) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\python311\lib\site-packages (from nltk>=3.2.1->newspaper3k) (2024.11.6)
# Requirement already satisfied: tqdm in c:\python311\lib\site-packages (from nltk>=3.2.1->newspaper3k) (4.66.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\python311\lib\site-packages (from requests>=2.10.0->newspaper3k) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\python311\lib\site-packages (from requests>=2.10.0->newspaper3k) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\python311\lib\site-packages (from requests>=2.10.0->newspaper3k) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\asus\appdata\roaming\python\python311\site-packages (from requests>=2.10.0->newspaper3k) (2024.2.2)
# Requirement already satisfied: requests-file>=1.4 in c:\users\asus\appdata\roaming\python\python311\site-packages (from tldextract>=2.0.1->newspaper3k) (2.1.0)
# Requirement already satisfied: filelock>=3.0.8 in c:\users\asus\appdata\roaming\python\python311\site-packages (from tldextract>=2.0.1->newspaper3k) (3.13.1)
# Requirement already satisfied: colorama in c:\python311\lib\site-packages (from click->nltk>=3.2.1->newspaper3k) (0.4.6)
# WARNING: Ignoring invalid distribution ~ip (C:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Python311\Lib\site-packages)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import requests
import pandas as pd
import time
import random
from bs4 import BeautifulSoup
from googlesearch import search  # Alternative to GoogleNews API
from fake_useragent import UserAgent
import tweepy
from selenium import webdriver

# Load previously selected top 250 stocks
df_selected_stocks = pd.read_csv("../data/top_250_stocks.csv")

# Create directories for saving files
import os
os.makedirs("sentiment_data", exist_ok=True)

# Function to introduce long random delays
def wait():
    delay = random.randint(30, 60)  # Longer delay (30-60 sec) to prevent bans
    print(f"Sleeping for {delay} seconds to avoid detection...")
    time.sleep(delay)

# ---------------- STEP 1: FETCH FINANCIAL NEWS USING GOOGLE SEARCH ---------------- #

def fetch_google_news(stock_name):
    query = f"{stock_name} stock news site:moneycontrol.com OR site:economictimes.indiatimes.com OR site:bloombergquint.com"
    
    news_data = []
    headers = {"User-Agent": UserAgent().random}  # Use random user-agent
    
    try:
        # Search Google for top news articles
        search_results = list(search(query, num_results=5, lang="en"))  # Get top 5 links
        
        for link in search_results:
            response = requests.get(link, headers=headers, timeout=10)  # Fetch page
            soup = BeautifulSoup(response.text, "html.parser")
            
            title = soup.title.string if soup.title else "No Title"
            news_data.append({
                "Company Name": stock_name,
                "ISIN Code": df_selected_stocks.loc[df_selected_stocks["Company Name"] == stock_name, "ISIN Code"].values[0],
                "News URL": link,
                "News Title": title
            })
        
        return news_data
    
    except Exception as e:
        print(f"Error fetching news for {stock_name}: {e}")
        return []

# Loop through selected stocks and fetch news
all_news = []
for stock in df_selected_stocks["Company Name"]:
    all_news.extend(fetch_google_news(stock))
    wait()  # Longer wait to prevent 429

# Save news data
df_news = pd.DataFrame(all_news)
df_news.to_csv("sentiment_data/long_term_news_data.csv", index=False)
print("✅ Long-Term News Data Saved Successfully!")

# ---------------- STEP 2: SCRAPE NSE COMPANY FILINGS ---------------- #

options = webdriver.ChromeOptions()
options.add_argument("--headless")  # Run in background
options.add_argument(f"user-agent={UserAgent().random}")  # Rotate user agents
driver = webdriver.Chrome(options=options)

def get_company_filings(stock_name):
    url = f"https://www.nseindia.com/companies-listing/corporate-filings/{stock_name}"
    
    try:
        driver.get(url)
        wait()  # Random delay

        soup = BeautifulSoup(driver.page_source, "html.parser")
        reports = soup.find_all("div", class_="report-item")

        filings = []
        for report in reports[:10]:  # Get last 10 years' filings
            filings.append({
                "Company Name": stock_name,
                "ISIN Code": df_selected_stocks.loc[df_selected_stocks["Company Name"] == stock_name, "ISIN Code"].values[0],
                "Date": report.find("span", class_="date").text.strip(),
                "Title": report.find("h3").text.strip(),
                "Link": report.find("a")["href"]
            })

        return filings
    except Exception as e:
        print(f"Error fetching filings for {stock_name}: {e}")
        return []

# Get filings for selected stocks
all_filings = []
for stock in df_selected_stocks["Company Name"]:
    all_filings.extend(get_company_filings(stock))
    wait()

driver.quit()

# Save company filings data
df_filings = pd.DataFrame(all_filings)
df_filings.to_csv("sentiment_data/historical_company_filings.csv", index=False)
print("✅ Company Filings Data Saved Successfully!")

# ---------------- STEP 3: FETCH SOCIAL MEDIA SENTIMENT FROM TWITTER ---------------- #

# Twitter API Credentials (Get from developer.twitter.com)
BEARER_TOKEN = "your_bearer_token"

client = tweepy.Client(bearer_token=BEARER_TOKEN)

def fetch_tweets(stock_symbol):
    query = f"{stock_symbol} stock -is:retweet lang:en"
    
    try:
        tweets = client.search_recent_tweets(query=query, max_results=100)
        tweet_data = []
        
        for tweet in tweets.data:
            tweet_data.append({
                "Company Name": stock_symbol,
                "ISIN Code": df_selected_stocks.loc[df_selected_stocks["Company Name"] == stock_symbol, "ISIN Code"].values[0],
                "Date": tweet.created_at,
                "Tweet": tweet.text
            })

        return tweet_data
    except Exception as e:
        print(f"Error fetching tweets for {stock_symbol}: {e}")
        return []

# Fetch tweets for selected stocks
all_tweets = []
for stock in df_selected_stocks["Company Name"]:
    all_tweets.extend(fetch_tweets(stock))
    wait()

# Save Twitter sentiment data
df_tweets = pd.DataFrame(all_tweets)
df_tweets.to_csv("sentiment_data/long_term_twitter_sentiment.csv", index=False)
print("✅ Long-Term Twitter Sentiments Saved Successfully!")

# ---------------- FINAL OUTPUT ---------------- #
print("\n✅ Sentiment Analysis Data Collection Completed Successfully!")
# Out:
# Error fetching news for 360 ONE WAM Ltd.: 429 Client Error: Too Many Requests for url: https://www.google.com/sorry/index?continue=https://www.google.com/search%3Fq%3D360%2BONE%2BWAM%2BLtd.%2Bstock%2Bnews%2Bsite%253Amoneycontrol.com%2BOR%2Bsite%253Aeconomictimes.indiatimes.com%2BOR%2Bsite%253Abloombergquint.com%26num%3D7%26hl%3Den%26start%3D0%26safe%3Dactive&hl=en&q=EgSVKD42GNWSmb4GIjACo9gWuXbsJkagf5cUJN4k93cArGH12sTn94yDMdiU8g6xxl_lsX1fqBBxEcVhF48yAXJaAUM
# Sleeping for 43 seconds to avoid detection...
# Error fetching news for AU Small Finance Bank Ltd.: 429 Client Error: Too Many Requests for url: https://www.google.com/sorry/index?continue=https://www.google.com/search%3Fq%3DAU%2BSmall%2BFinance%2BBank%2BLtd.%2Bstock%2Bnews%2Bsite%253Amoneycontrol.com%2BOR%2Bsite%253Aeconomictimes.indiatimes.com%2BOR%2Bsite%253Abloombergquint.com%26num%3D7%26hl%3Den%26start%3D0%26safe%3Dactive&hl=en&q=EgSVKD42GIKTmb4GIjDtGtPVi9wvLNcg1nCjonxINUunKQxe3O1LfMJOcGkY5nhXPgU_aa2B6G-4mD5h7WUyAXJaAUM
# Sleeping for 50 seconds to avoid detection...
# Error fetching news for Aadhar Housing Finance Ltd.: 429 Client Error: Too Many Requests for url: https://www.google.com/sorry/index?continue=https://www.google.com/search%3Fq%3DAadhar%2BHousing%2BFinance%2BLtd.%2Bstock%2Bnews%2Bsite%253Amoneycontrol.com%2BOR%2Bsite%253Aeconomictimes.indiatimes.com%2BOR%2Bsite%253Abloombergquint.com%26num%3D7%26hl%3Den%26start%3D0%26safe%3Dactive&hl=en&q=EgSVKD42GLaTmb4GIjCzdU2O5JIU8Tk_ozzKGMHk4Mn-NyRTmOHSIMC02mPdoFbCgHjL2_FtPvzcVGrSC_oyAXJaAUM
# Sleeping for 43 seconds to avoid detection...
# Error fetching news for Aavas Financiers Ltd.: 429 Client Error: Too Many Requests for url: https://www.google.com/sorry/index?continue=https://www.google.com/search%3Fq%3DAavas%2BFinanciers%2BLtd.%2Bstock%2Bnews%2Bsite%253Amoneycontrol.com%2BOR%2Bsite%253Aeconomictimes.indiatimes.com%2BOR%2Bsite%253Abloombergquint.com%26num%3D7%26hl%3Den%26start%3D0%26safe%3Dactive&hl=en&q=EgSVKD42GOSTmb4GIjAxgu38DQoYFKruo8EHuTqDnKU8L6lVyubxDGzgeoYQrSh1ZF6pLQljArXXTXJULC8yAXJaAUM
# Sleeping for 36 seconds to avoid detection...
# Error fetching news for Aditya Birla Capital Ltd.: 429 Client Error: Too Many Requests for url: https://www.google.com/sorry/index?continue=https://www.google.com/search%3Fq%3DAditya%2BBirla%2BCapital%2BLtd.%2Bstock%2Bnews%2Bsite%253Amoneycontrol.com%2BOR%2Bsite%253Aeconomictimes.indiatimes.com%2BOR%2Bsite%253Abloombergquint.com%26num%3D7%26hl%3Den%26start%3D0%26safe%3Dactive&hl=en&q=EgSVKD42GIqUmb4GIjANpZVVb8dJGv_RUh-eZQpPe39_nDve32xAFBaYG_i41d0gHKmLCRK5LJyR6KXk5VcyAXJaAUM
# Sleeping for 30 seconds to avoid detection...
# Error fetching news for Aditya Birla Sun Life AMC Ltd.: 429 Client Error: Too Many Requests for url: https://www.google.com/sorry/index?continue=https://www.google.com/search%3Fq%3DAditya%2BBirla%2BSun%2BLife%2BAMC%2BLtd.%2Bstock%2Bnews%2Bsite%253Amoneycontrol.com%2BOR%2Bsite%253Aeconomictimes.indiatimes.com%2BOR%2Bsite%253Abloombergquint.com%26num%3D7%26hl%3Den%26start%3D0%26safe%3Dactive&hl=en&q=EgSVKD42GKqUmb4GIjAyXQ6GQEvBCaya51eked6unu9inZGnT5XVaVJoJA1QL0Zlymjvu-NXWUvjztCBmtcyAXJaAUM
# Sleeping for 41 seconds to avoid detection...
# Error fetching news for Anand Rathi Wealth Ltd.: 429 Client Error: Too Many Requests for url: https://www.google.com/sorry/index?continue=https://www.google.com/search%3Fq%3DAnand%2BRathi%2BWealth%2BLtd.%2Bstock%2Bnews%2Bsite%253Amoneycontrol.com%2BOR%2Bsite%253Aeconomictimes.indiatimes.com%2BOR%2Bsite%253Abloombergquint.com%26num%3D7%26hl%3Den%26start%3D0%26safe%3Dactive&hl=en&q=EgSVKD42GNWUmb4GIjA6HMNjovJsz54rCCvq-WwmHN4qrjxoeWI6OLjHQrMopCgVc4M5A-Q0fxL2I1qcYIUyAXJaAUM
# Sleeping for 30 seconds to avoid detection...
# Error fetching news for Angel One Ltd.: 429 Client Error: Too Many Requests for url: https://www.google.com/sorry/index?continue=https://www.google.com/search%3Fq%3DAngel%2BOne%2BLtd.%2Bstock%2Bnews%2Bsite%253Amoneycontrol.com%2BOR%2Bsite%253Aeconomictimes.indiatimes.com%2BOR%2Bsite%253Abloombergquint.com%26num%3D7%26hl%3Den%26start%3D0%26safe%3Dactive&hl=en&q=EgSVKD42GPWUmb4GIjC0VXsHIPoZBBfRt7OhPCvFrayKGgmgSENR9QzfPMJ2jeldjbX_bwCbVj0_JEA3jFQyAXJaAUM
# Sleeping for 36 seconds to avoid detection...
# Error fetching news for Aptus Value Housing Finance India Ltd.: 429 Client Error: Too Many Requests for url: https://www.google.com/sorry/index?continue=https://www.google.com/search%3Fq%3DAptus%2BValue%2BHousing%2BFinance%2BIndia%2BLtd.%2Bstock%2Bnews%2Bsite%253Amoneycontrol.com%2BOR%2Bsite%253Aeconomictimes.indiatimes.com%2BOR%2Bsite%253Abloombergquint.com%26num%3D7%26hl%3Den%26start%3D0%26safe%3Dactive&hl=en&q=EgSVKD42GJuVmb4GIjAUhVfjUG76fPZxiLlCeoTJHHOKHYeVA_sDL6tW6704ZmhB4YvBMA4AgIB7kYlrQNoyAXJaAUM
# Sleeping for 52 seconds to avoid detection...
# Error fetching news for Axis Bank Ltd.: 429 Client Error: Too Many Requests for url: https://www.google.com/sorry/index?continue=https://www.google.com/search%3Fq%3DAxis%2BBank%2BLtd.%2Bstock%2Bnews%2Bsite%253Amoneycontrol.com%2BOR%2Bsite%253Aeconomictimes.indiatimes.com%2BOR%2Bsite%253Abloombergquint.com%26num%3D7%26hl%3Den%26start%3D0%26safe%3Dactive&hl=en&q=EgSVKD42GNGVmb4GIjBTpcAMZWdPUb07xyIxx9PESoSZEaq2kKZcMzAu4Vr1ghevTfpO4vvq_iFsSc7ZovUyAXJaAUM
# Sleeping for 44 seconds to avoid detection...
# Error fetching news for BSE Ltd.: 429 Client Error: Too Many Requests for url: https://www.google.com/sorry/index?continue=https://www.google.com/search%3Fq%3DBSE%2BLtd.%2Bstock%2Bnews%2Bsite%253Amoneycontrol.com%2BOR%2Bsite%253Aeconomictimes.indiatimes.com%2BOR%2Bsite%253Abloombergquint.com%26num%3D7%26hl%3Den%26start%3D0%26safe%3Dactive&hl=en&q=EgSVKD42GP-Vmb4GIjBHHjmgD7psUFmk0J-bjn9zt9RnSmqwq5GJ061KWFsrobCofhTze7pIn14Y5f8VyCMyAXJaAUM
# Sleeping for 50 seconds to avoid detection...
# Error fetching news for Bajaj Finance Ltd.: 429 Client Error: Too Many Requests for url: https://www.google.com/sorry/index?continue=https://www.google.com/search%3Fq%3DBajaj%2BFinance%2BLtd.%2Bstock%2Bnews%2Bsite%253Amoneycontrol.com%2BOR%2Bsite%253Aeconomictimes.indiatimes.com%2BOR%2Bsite%253Abloombergquint.com%26num%3D7%26hl%3Den%26start%3D0%26safe%3Dactive&hl=en&q=EgSVKD42GLOWmb4GIjAgJXTcRmTAruxG-9j09z4THCF1eDSZDUIwSxyOGxupRJlqPzuKu7o7EoEeJjO9cwIyAXJaAUM
# Sleeping for 40 seconds to avoid detection...
# Error fetching news for Bajaj Finserv Ltd.: 429 Client Error: Too Many Requests for url: https://www.google.com/sorry/index?continue=https://www.google.com/search%3Fq%3DBajaj%2BFinserv%2BLtd.%2Bstock%2Bnews%2Bsite%253Amoneycontrol.com%2BOR%2Bsite%253Aeconomictimes.indiatimes.com%2BOR%2Bsite%253Abloombergquint.com%26num%3D7%26hl%3Den%26start%3D0%26safe%3Dactive&hl=en&q=EgSVKD42GN2Wmb4GIjBkDANS26TBoE9xd8Y8_yPJdFNrZYJ7h8qFR_pFHnZqxSvntcK-To1Up1kR5fx4gCkyAXJaAUM
# Sleeping for 37 seconds to avoid detection...
# Error fetching news for Bajaj Holdings & Investment Ltd.: 429 Client Error: Too Many Requests for url: https://www.google.com/sorry/index?continue=https://www.google.com/search%3Fq%3DBajaj%2BHoldings%2B%2526%2BInvestment%2BLtd.%2Bstock%2Bnews%2Bsite%253Amoneycontrol.com%2BOR%2Bsite%253Aeconomictimes.indiatimes.com%2BOR%2Bsite%253Abloombergquint.com%26num%3D7%26hl%3Den%26start%3D0%26safe%3Dactive&hl=en&q=EgSVKD42GIWXmb4GIjCYUGeVxIwDMTkcVSzp5pjH2gdUKDrAw5MV7j7EZPR7TsXCdXk22nPPNa8RqTTEnVgyAXJaAUM
# Sleeping for 56 seconds to avoid detection...
# Error fetching news for Bandhan Bank Ltd.: 429 Client Error: Too Many Requests for url: https://www.google.com/sorry/index?continue=https://www.google.com/search%3Fq%3DBandhan%2BBank%2BLtd.%2Bstock%2Bnews%2Bsite%253Amoneycontrol.com%2BOR%2Bsite%253Aeconomictimes.indiatimes.com%2BOR%2Bsite%253Abloombergquint.com%26num%3D7%26hl%3Den%26start%3D0%26safe%3Dactive&hl=en&q=EgSVKD42GL-Xmb4GIjCe7gSKQzqlxyVwzZMtWzoYlcXksRjT87y6dPXDwDi7MywH9R4Cei1zS00O1mXTuhEyAXJaAUM
# Sleeping for 43 seconds to avoid detection...
# Error fetching news for Bank of Baroda: 429 Client Error: Too Many Requests for url: https://www.google.com/sorry/index?continue=https://www.google.com/search%3Fq%3DBank%2Bof%2BBaroda%2Bstock%2Bnews%2Bsite%253Amoneycontrol.com%2BOR%2Bsite%253Aeconomictimes.indiatimes.com%2BOR%2Bsite%253Abloombergquint.com%26num%3D7%26hl%3Den%26start%3D0%26safe%3Dactive&hl=en&q=EgSVKD42GO2Xmb4GIjCNerctrZ2dMAiERRFUcsvhdb6u5QNEqbDciOYoQqt3V39gZgkmAsHeJHkibAnqRmgyAXJaAUM
# Sleeping for 35 seconds to avoid detection...
# Error fetching news for Bank of India: 429 Client Error: Too Many Requests for url: https://www.google.com/sorry/index?continue=https://www.google.com/search%3Fq%3DBank%2Bof%2BIndia%2Bstock%2Bnews%2Bsite%253Amoneycontrol.com%2BOR%2Bsite%253Aeconomictimes.indiatimes.com%2BOR%2Bsite%253Abloombergquint.com%26num%3D7%26hl%3Den%26start%3D0%26safe%3Dactive&hl=en&q=EgSVKD42GJOYmb4GIjCFQv4q4zaocaEhZRPsd4jH11TAMdS56_hkkpWcEUTPHCue_eq1E8r82YL41JFraCMyAXJaAUM
# Sleeping for 58 seconds to avoid detection...
# Error fetching news for Bank of Maharashtra: 429 Client Error: Too Many Requests for url: https://www.google.com/sorry/index?continue=https://www.google.com/search%3Fq%3DBank%2Bof%2BMaharashtra%2Bstock%2Bnews%2Bsite%253Amoneycontrol.com%2BOR%2Bsite%253Aeconomictimes.indiatimes.com%2BOR%2Bsite%253Abloombergquint.com%26num%3D7%26hl%3Den%26start%3D0%26safe%3Dactive&hl=en&q=EgSVKD42GNCYmb4GIjA_M4peqEvs7Vc8dIxSfXV_VBuVlyGUSXgBDOs929PuLATh3W3sQXcCyFJwL9BOdAwyAXJaAUM
# Sleeping for 58 seconds to avoid detection...
# Error fetching news for CRISIL Ltd.: 429 Client Error: Too Many Requests for url: https://www.google.com/sorry/index?continue=https://www.google.com/search%3Fq%3DCRISIL%2BLtd.%2Bstock%2Bnews%2Bsite%253Amoneycontrol.com%2BOR%2Bsite%253Aeconomictimes.indiatimes.com%2BOR%2Bsite%253Abloombergquint.com%26num%3D7%26hl%3Den%26start%3D0%26safe%3Dactive&hl=en&q=EgSVKD42GIyZmb4GIjBuq7j-dAthwYByXlHdOccVX3W_tZh-xq3rXzgWOx6xhAgn-JBnxlA5x-owT-uen28yAXJaAUM
# Sleeping for 46 seconds to avoid detection...
# Error fetching news for Can Fin Homes Ltd.: 429 Client Error: Too Many Requests for url: https://www.google.com/sorry/index?continue=https://www.google.com/search%3Fq%3DCan%2BFin%2BHomes%2BLtd.%2Bstock%2Bnews%2Bsite%253Amoneycontrol.com%2BOR%2Bsite%253Aeconomictimes.indiatimes.com%2BOR%2Bsite%253Abloombergquint.com%26num%3D7%26hl%3Den%26start%3D0%26safe%3Dactive&hl=en&q=EgSVKD42GLyZmb4GIjCPf22atdXYMtTYfEVsfvEtrYUOmlk9A3-9_WiGa_ARk7rLGmI2g046ArzdTv_hOmAyAXJaAUM
# Sleeping for 45 seconds to avoid detection...
# Error fetching news for Canara Bank: 429 Client Error: Too Many Requests for url: https://www.google.com/sorry/index?continue=https://www.google.com/search%3Fq%3DCanara%2BBank%2Bstock%2Bnews%2Bsite%253Amoneycontrol.com%2BOR%2Bsite%253Aeconomictimes.indiatimes.com%2BOR%2Bsite%253Abloombergquint.com%26num%3D7%26hl%3Den%26start%3D0%26safe%3Dactive&hl=en&q=EgSVKD42GOyZmb4GIjB3mWuKT3otW7bE7Ai69albP51fF0TFrwg68rszim_UzbKp0Jl44hBjngiiOFzgqHgyAXJaAUM
# Sleeping for 50 seconds to avoid detection...
# Error fetching news for Capri Global Capital Ltd.: 429 Client Error: Too Many Requests for url: https://www.google.com/sorry/index?continue=https://www.google.com/search%3Fq%3DCapri%2BGlobal%2BCapital%2BLtd.%2Bstock%2Bnews%2Bsite%253Amoneycontrol.com%2BOR%2Bsite%253Aeconomictimes.indiatimes.com%2BOR%2Bsite%253Abloombergquint.com%26num%3D7%26hl%3Den%26start%3D0%26safe%3Dactive&hl=en&q=EgSVKD42GKCamb4GIjBkMGHCWA1dprqmnHz58IF7bywHN2xA824NRr4mvZeDCEVNz40htQ-tJmTGkfrldYAyAXJaAUM
# Sleeping for 54 seconds to avoid detection...
