# %%
<a class="file" href="https://nsearchives.nseindia.com/content/indices/ind_nifty50list.csv" target="_blank">Download List of Nifty 50 stocks (.csv)</a>

# %%
import requests
import pandas as pd
import os
import time
import yfinance as yf

# Create directories for saving files
os.makedirs("nifty50_short_term_data", exist_ok=True)

# Step 1: Download Latest NIFTY 50 Stock List
def download_nifty50_list():
    url = "https://nsearchives.nseindia.com/content/indices/ind_nifty50list.csv"
    file_path = "nifty50_stocks.csv"

    headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; rv:102.0) Gecko/20100101 Firefox/102.0"}
    response = requests.get(url, headers=headers)

    if response.status_code == 200:
        with open(file_path, "wb") as file:
            file.write(response.content)
        print(f"✅ NIFTY 50 stock list downloaded successfully: {file_path}")

        df = pd.read_csv(file_path)
        df.columns = df.columns.str.strip()  # Clean column names
        return df
    else:
        print("❌ Failed to download NIFTY 50 stock list.")
        return None

# Step 2: Download Short-Term Price Data using yfinance
def download_stock_data_yfinance(stock_symbol, session):
    try:
        stock = yf.Ticker(stock_symbol, session=session)
        data = stock.history(period="1y", interval="1d")  # Fetch daily data for last 1 year

        if not data.empty:
            data.to_csv(f"nifty50_short_term_data/{stock_symbol}_1yr_data.csv")
            print(f"✅ Downloaded 1-year daily data for {stock_symbol}")
        else:
            print(f"⚠️ No data available for {stock_symbol}")

    except Exception as e:
        print(f"❌ Error fetching data for {stock_symbol}: {e}")

# Step 3: Handle IP Blocking by Using a Custom Session
def get_custom_yfinance_session():
    session = requests.Session()
    session.headers.update({"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"})
    return session

# Main Execution Flow
nifty50_df = download_nifty50_list()
if nifty50_df is not None:
    # Save stock list to CSV
    nifty50_df.to_csv("nifty50_stocks.csv", index=False)
    print("📁 Saved NIFTY 50 stock list to nifty50_stocks.csv.")

    # Get a session with a custom user-agent to avoid blocking
    session = get_custom_yfinance_session()

    # Download short-term price data for each stock
    for symbol in nifty50_df["Symbol"]:
        full_symbol = f"{symbol}.NS"  # NSE India format for yfinance
        download_stock_data_yfinance(full_symbol, session)

        # Avoid getting blocked by adding delay
        time.sleep(2)

print("\n✅ All short-term NIFTY 50 stock data downloaded successfully!")
# Out:
# ✅ NIFTY 50 stock list downloaded successfully: nifty50_stocks.csv
# 📁 Saved NIFTY 50 stock list to nifty50_stocks.csv.
# ✅ Downloaded 1-year daily data for ADANIENT.NS
# ✅ Downloaded 1-year daily data for ADANIPORTS.NS
# ✅ Downloaded 1-year daily data for APOLLOHOSP.NS
# ✅ Downloaded 1-year daily data for ASIANPAINT.NS
# ✅ Downloaded 1-year daily data for AXISBANK.NS
# ✅ Downloaded 1-year daily data for BAJAJ-AUTO.NS
# ✅ Downloaded 1-year daily data for BAJFINANCE.NS
# ✅ Downloaded 1-year daily data for BAJAJFINSV.NS
# ✅ Downloaded 1-year daily data for BEL.NS
# ✅ Downloaded 1-year daily data for BHARTIARTL.NS
# ✅ Downloaded 1-year daily data for CIPLA.NS
# ✅ Downloaded 1-year daily data for COALINDIA.NS
# ✅ Downloaded 1-year daily data for DRREDDY.NS
# ✅ Downloaded 1-year daily data for EICHERMOT.NS
# ✅ Downloaded 1-year daily data for GRASIM.NS
# ✅ Downloaded 1-year daily data for HCLTECH.NS
# ✅ Downloaded 1-year daily data for HDFCBANK.NS
# ✅ Downloaded 1-year daily data for HDFCLIFE.NS
# ✅ Downloaded 1-year daily data for HEROMOTOCO.NS
# ✅ Downloaded 1-year daily data for HINDALCO.NS
# ✅ Downloaded 1-year daily data for HINDUNILVR.NS
# ✅ Downloaded 1-year daily data for ICICIBANK.NS
# ✅ Downloaded 1-year daily data for ITC.NS
# ✅ Downloaded 1-year daily data for INDUSINDBK.NS
# ✅ Downloaded 1-year daily data for INFY.NS
# ✅ Downloaded 1-year daily data for JSWSTEEL.NS
# ✅ Downloaded 1-year daily data for JIOFIN.NS
# ✅ Downloaded 1-year daily data for KOTAKBANK.NS
# ✅ Downloaded 1-year daily data for LT.NS
# ✅ Downloaded 1-year daily data for M&M.NS
# ✅ Downloaded 1-year daily data for MARUTI.NS
# ✅ Downloaded 1-year daily data for NTPC.NS
# ✅ Downloaded 1-year daily data for NESTLEIND.NS
# ✅ Downloaded 1-year daily data for ONGC.NS
# ✅ Downloaded 1-year daily data for POWERGRID.NS
# ✅ Downloaded 1-year daily data for RELIANCE.NS
# ✅ Downloaded 1-year daily data for SBILIFE.NS
# ✅ Downloaded 1-year daily data for SHRIRAMFIN.NS
# ✅ Downloaded 1-year daily data for SBIN.NS
# ✅ Downloaded 1-year daily data for SUNPHARMA.NS
# ✅ Downloaded 1-year daily data for TCS.NS
# ✅ Downloaded 1-year daily data for TATACONSUM.NS
# ✅ Downloaded 1-year daily data for TATAMOTORS.NS
# ✅ Downloaded 1-year daily data for TATASTEEL.NS
# ✅ Downloaded 1-year daily data for TECHM.NS
# ✅ Downloaded 1-year daily data for TITAN.NS
# ✅ Downloaded 1-year daily data for TRENT.NS
# ✅ Downloaded 1-year daily data for ULTRACEMCO.NS
# ✅ Downloaded 1-year daily data for WIPRO.NS
# ✅ Downloaded 1-year daily data for ZOMATO.NS
#
# ✅ All short-term NIFTY 50 stock data downloaded successfully!

# %%
import os
import datetime
import time
import pandas as pd
import requests
from openchart import NSEData

# Initialize OpenChart NSEData
nse = NSEData()

# Retry downloading master data if it fails
max_retries = 5
retry_count = 0

while retry_count < max_retries:
    try:
        print(f"⏳ Attempt {retry_count + 1}: Downloading NSE Master Data...")
        nse.download()  # Removed the 'timeout' argument

        if 'NSE' in nse.symbols and not nse.symbols['NSE'].empty:
            print("✅ NSE master data downloaded successfully.")
            break
        else:
            print("⚠️ No data received. Retrying...")

    except Exception as e:
        print(f"❌ Error downloading NSE master data: {e}")

    retry_count += 1
    time.sleep(5)

if retry_count == max_retries:
    print("❌ Failed to download NSE master data after multiple attempts.")
    exit()

# Load NIFTY 50 Stock List
nifty50_csv_url = "https://archives.nseindia.com/content/indices/ind_nifty50list.csv"
nifty50_csv_file = "nifty50_stocks.csv"

try:
    response = requests.get(nifty50_csv_url, timeout=10)
    response.raise_for_status()  # Raise an error for bad status codes

    with open(nifty50_csv_file, "wb") as file:
        file.write(response.content)
    print(f"✅ NIFTY 50 stock list downloaded: {nifty50_csv_file}")

except requests.exceptions.RequestException as e:
    print(f"❌ Failed to download NIFTY 50 stock list: {e}")
    exit()

# Read the CSV into a DataFrame
nifty50_df = pd.read_csv(nifty50_csv_file)

# Define Timeframes and Lookback Periods
timeframes = {
    '1m': 3,
    '3m': 3,
    '5m': 3,
    '10m': 3,
    '15m': 3,
    '30m': 3,
    '1h': 5
}

# Create Directory for Data Storage
os.makedirs("nifty50_intraday_data", exist_ok=True)

# Fetch and Save Intraday Data
def download_intraday_data(symbol):
    """Fetch and save intraday data for different timeframes."""
    for interval, days in timeframes.items():
        try:
            print(f"📥 Downloading {interval} data for {symbol} ({days} days)...")
            end_date = datetime.datetime.now()
            start_date = end_date - datetime.timedelta(days=days)

            df = nse.historical(
                symbol=symbol,
                exchange='NSE',
                start=start_date,
                end=end_date,
                interval=interval
            )

            if df is not None and not df.empty:
                df.reset_index(inplace=True)  # Ensure Timestamp is a column
                file_path = f"nifty50_intraday_data/{symbol}_{interval}.csv"
                df.to_csv(file_path, index=False)  # Save without extra index
                print(f"✅ Saved {interval} data to {file_path}")
            else:
                print(f"⚠️ No data available for {symbol} ({interval})")

            time.sleep(1)  # Avoid API rate limits

        except Exception as e:
            print(f"❌ Error fetching {interval} data for {symbol}: {e}")
            with open("error_log.txt", "a") as log_file:
                log_file.write(f"Error fetching {interval} data for {symbol}: {e}\n")

# Loop Through NIFTY 50 Stocks
for symbol in nifty50_df["Symbol"]:
    download_intraday_data(symbol)

print("\n✅ All intraday data downloaded successfully!")
# Out:
# ⏳ Attempt 1: Downloading NSE Master Data...
# NSE data shape: (2962, 4)
# NFO data shape: (77433, 4)
# NSE and NFO data downloaded successfully.
# ❌ Error downloading NSE master data: 'NSEData' object has no attribute 'symbols'
# ⏳ Attempt 2: Downloading NSE Master Data...
# NSE data shape: (2962, 4)
# NFO data shape: (77433, 4)
# NSE and NFO data downloaded successfully.
# ❌ Error downloading NSE master data: 'NSEData' object has no attribute 'symbols'
# ⏳ Attempt 3: Downloading NSE Master Data...
# NSE data shape: (2962, 4)
# NFO data shape: (77433, 4)
# NSE and NFO data downloaded successfully.
# ❌ Error downloading NSE master data: 'NSEData' object has no attribute 'symbols'
# ⏳ Attempt 4: Downloading NSE Master Data...
# NSE data shape: (2962, 4)
# NFO data shape: (77433, 4)
# NSE and NFO data downloaded successfully.
# ❌ Error downloading NSE master data: 'NSEData' object has no attribute 'symbols'
# ⏳ Attempt 5: Downloading NSE Master Data...
# NSE data shape: (2962, 4)
# NFO data shape: (77433, 4)
# NSE and NFO data downloaded successfully.
# ❌ Error downloading NSE master data: 'NSEData' object has no attribute 'symbols'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 30
#      27         print(f"❌ Error downloading NSE master data: {e}")
#      29     retry_count += 1
# ---> 30     time.sleep(5)
#      32 if retry_count == max_retries:
#      33     print("❌ Failed to download NSE master data after multiple attempts.")
#
# KeyboardInterrupt:

# %%
import os
import datetime
import time
import pandas as pd
import requests
from openchart import NSEData

# Initialize OpenChart NSEData
nse = NSEData()

def download_master_data():
    """Attempt to download master data with retries."""
    max_retries = 5
    retry_count = 0

    while retry_count < max_retries:
        try:
            print(f"⏳ Attempt {retry_count + 1}: Downloading NSE Master Data...")
            nse.download()
            print("✅ NSE master data downloaded successfully.")
            return True

        except Exception as e:
            print(f"❌ Error downloading NSE master data: {e}")
            retry_count += 1
            time.sleep(5)

    print("❌ Failed to download NSE master data after multiple attempts.")
    return False

def download_nifty50_stock_list():
    """Download the NIFTY 50 stock list CSV and return the DataFrame."""
    nifty50_csv_url = "https://archives.nseindia.com/content/indices/ind_nifty50list.csv"
    nifty50_csv_file = "nifty50_stocks.csv"

    try:
        response = requests.get(nifty50_csv_url, timeout=10)
        response.raise_for_status()

        with open(nifty50_csv_file, "wb") as file:
            file.write(response.content)

        print(f"✅ NIFTY 50 stock list downloaded: {nifty50_csv_file}")
        return pd.read_csv(nifty50_csv_file)

    except requests.exceptions.RequestException as e:
        print(f"❌ Failed to download NIFTY 50 stock list: {e}")
        return None

# Define Timeframes and Lookback Periods
timeframes = {
    '1m': 3,
    '3m': 3,
    '5m': 3,
    '10m': 3,
    '15m': 3,
    '30m': 3,
    '1h': 5
}

# Create Directory for Data Storage
os.makedirs("nifty50_intraday_data", exist_ok=True)

def download_intraday_data(symbol):
    """Fetch and save intraday data for different timeframes."""
    for interval, days in timeframes.items():
        try:
            print(f"📥 Downloading {interval} data for {symbol} ({days} days)...")
            end_date = datetime.datetime.now()
            start_date = end_date - datetime.timedelta(days=days)

            df = nse.historical(
                symbol=symbol,
                exchange='NSE',
                start=start_date,
                end=end_date,
                interval=interval
            )

            if df is not None and not df.empty:
                df.reset_index(inplace=True)
                file_path = f"nifty50_intraday_data/{symbol}_{interval}.csv"
                df.to_csv(file_path, index=False)
                print(f"✅ Saved {interval} data to {file_path}")
            else:
                print(f"⚠️ No data available for {symbol} ({interval})")

            time.sleep(1)  # Avoid API rate limits

        except Exception as e:
            print(f"❌ Error fetching {interval} data for {symbol}: {e}")
            with open("error_log.txt", "a") as log_file:
                log_file.write(f"Error fetching {interval} data for {symbol}: {e}\n")

def main():
    if not download_master_data():
        exit()

    nifty50_df = download_nifty50_stock_list()
    if nifty50_df is None:
        exit()

    for symbol in nifty50_df["Symbol"]:
        download_intraday_data(symbol)

    print("\n✅ All intraday data downloaded successfully!")

if __name__ == "__main__":
    main()
# Out:
# ⏳ Attempt 1: Downloading NSE Master Data...
# NSE data shape: (2962, 4)
# NFO data shape: (77433, 4)
# NSE and NFO data downloaded successfully.
# ✅ NSE master data downloaded successfully.
# ✅ NIFTY 50 stock list downloaded: nifty50_stocks.csv
# 📥 Downloading 1m data for ADANIENT (3 days)...
# ✅ Saved 1m data to nifty50_intraday_data/ADANIENT_1m.csv
# 📥 Downloading 3m data for ADANIENT (3 days)...
# ✅ Saved 3m data to nifty50_intraday_data/ADANIENT_3m.csv
# 📥 Downloading 5m data for ADANIENT (3 days)...
# ✅ Saved 5m data to nifty50_intraday_data/ADANIENT_5m.csv
# 📥 Downloading 10m data for ADANIENT (3 days)...
# ✅ Saved 10m data to nifty50_intraday_data/ADANIENT_10m.csv
# 📥 Downloading 15m data for ADANIENT (3 days)...
# ✅ Saved 15m data to nifty50_intraday_data/ADANIENT_15m.csv
# 📥 Downloading 30m data for ADANIENT (3 days)...
# ✅ Saved 30m data to nifty50_intraday_data/ADANIENT_30m.csv
# 📥 Downloading 1h data for ADANIENT (5 days)...
# ✅ Saved 1h data to nifty50_intraday_data/ADANIENT_1h.csv
# 📥 Downloading 1m data for ADANIPORTS (3 days)...
# ✅ Saved 1m data to nifty50_intraday_data/ADANIPORTS_1m.csv
# 📥 Downloading 3m data for ADANIPORTS (3 days)...
# ✅ Saved 3m data to nifty50_intraday_data/ADANIPORTS_3m.csv
# 📥 Downloading 5m data for ADANIPORTS (3 days)...
# ✅ Saved 5m data to nifty50_intraday_data/ADANIPORTS_5m.csv
# 📥 Downloading 10m data for ADANIPORTS (3 days)...
# ✅ Saved 10m data to nifty50_intraday_data/ADANIPORTS_10m.csv
# 📥 Downloading 15m data for ADANIPORTS (3 days)...
# ✅ Saved 15m data to nifty50_intraday_data/ADANIPORTS_15m.csv
# 📥 Downloading 30m data for ADANIPORTS (3 days)...
# ✅ Saved 30m data to nifty50_intraday_data/ADANIPORTS_30m.csv
# 📥 Downloading 1h data for ADANIPORTS (5 days)...
# ✅ Saved 1h data to nifty50_intraday_data/ADANIPORTS_1h.csv
# 📥 Downloading 1m data for APOLLOHOSP (3 days)...
# ✅ Saved 1m data to nifty50_intraday_data/APOLLOHOSP_1m.csv
# 📥 Downloading 3m data for APOLLOHOSP (3 days)...
# ✅ Saved 3m data to nifty50_intraday_data/APOLLOHOSP_3m.csv
# 📥 Downloading 5m data for APOLLOHOSP (3 days)...
# ✅ Saved 5m data to nifty50_intraday_data/APOLLOHOSP_5m.csv
# 📥 Downloading 10m data for APOLLOHOSP (3 days)...
# ✅ Saved 10m data to nifty50_intraday_data/APOLLOHOSP_10m.csv
# 📥 Downloading 15m data for APOLLOHOSP (3 days)...
# ✅ Saved 15m data to nifty50_intraday_data/APOLLOHOSP_15m.csv
# 📥 Downloading 30m data for APOLLOHOSP (3 days)...
# ✅ Saved 30m data to nifty50_intraday_data/APOLLOHOSP_30m.csv
# 📥 Downloading 1h data for APOLLOHOSP (5 days)...
# ✅ Saved 1h data to nifty50_intraday_data/APOLLOHOSP_1h.csv
# 📥 Downloading 1m data for ASIANPAINT (3 days)...
# ✅ Saved 1m data to nifty50_intraday_data/ASIANPAINT_1m.csv
# 📥 Downloading 3m data for ASIANPAINT (3 days)...
# ✅ Saved 3m data to nifty50_intraday_data/ASIANPAINT_3m.csv
# 📥 Downloading 5m data for ASIANPAINT (3 days)...
# ✅ Saved 5m data to nifty50_intraday_data/ASIANPAINT_5m.csv
# 📥 Downloading 10m data for ASIANPAINT (3 days)...
# ✅ Saved 10m data to nifty50_intraday_data/ASIANPAINT_10m.csv
# 📥 Downloading 15m data for ASIANPAINT (3 days)...
# ✅ Saved 15m data to nifty50_intraday_data/ASIANPAINT_15m.csv
# 📥 Downloading 30m data for ASIANPAINT (3 days)...
# ✅ Saved 30m data to nifty50_intraday_data/ASIANPAINT_30m.csv
# 📥 Downloading 1h data for ASIANPAINT (5 days)...
# ✅ Saved 1h data to nifty50_intraday_data/ASIANPAINT_1h.csv
# 📥 Downloading 1m data for AXISBANK (3 days)...
# ✅ Saved 1m data to nifty50_intraday_data/AXISBANK_1m.csv
# 📥 Downloading 3m data for AXISBANK (3 days)...
# ✅ Saved 3m data to nifty50_intraday_data/AXISBANK_3m.csv
# 📥 Downloading 5m data for AXISBANK (3 days)...
# ✅ Saved 5m data to nifty50_intraday_data/AXISBANK_5m.csv
# 📥 Downloading 10m data for AXISBANK (3 days)...
# ✅ Saved 10m data to nifty50_intraday_data/AXISBANK_10m.csv
# 📥 Downloading 15m data for AXISBANK (3 days)...
# ✅ Saved 15m data to nifty50_intraday_data/AXISBANK_15m.csv
# 📥 Downloading 30m data for AXISBANK (3 days)...
# ✅ Saved 30m data to nifty50_intraday_data/AXISBANK_30m.csv
# 📥 Downloading 1h data for AXISBANK (5 days)...
# ✅ Saved 1h data to nifty50_intraday_data/AXISBANK_1h.csv
# 📥 Downloading 1m data for BAJAJ-AUTO (3 days)...
# ✅ Saved 1m data to nifty50_intraday_data/BAJAJ-AUTO_1m.csv
# 📥 Downloading 3m data for BAJAJ-AUTO (3 days)...
# ✅ Saved 3m data to nifty50_intraday_data/BAJAJ-AUTO_3m.csv
# 📥 Downloading 5m data for BAJAJ-AUTO (3 days)...
# ✅ Saved 5m data to nifty50_intraday_data/BAJAJ-AUTO_5m.csv
# 📥 Downloading 10m data for BAJAJ-AUTO (3 days)...
# ✅ Saved 10m data to nifty50_intraday_data/BAJAJ-AUTO_10m.csv
# 📥 Downloading 15m data for BAJAJ-AUTO (3 days)...
# ✅ Saved 15m data to nifty50_intraday_data/BAJAJ-AUTO_15m.csv
# 📥 Downloading 30m data for BAJAJ-AUTO (3 days)...
# ✅ Saved 30m data to nifty50_intraday_data/BAJAJ-AUTO_30m.csv
# 📥 Downloading 1h data for BAJAJ-AUTO (5 days)...
# ✅ Saved 1h data to nifty50_intraday_data/BAJAJ-AUTO_1h.csv
# 📥 Downloading 1m data for BAJFINANCE (3 days)...
# ✅ Saved 1m data to nifty50_intraday_data/BAJFINANCE_1m.csv
# 📥 Downloading 3m data for BAJFINANCE (3 days)...
# ✅ Saved 3m data to nifty50_intraday_data/BAJFINANCE_3m.csv
# 📥 Downloading 5m data for BAJFINANCE (3 days)...
# ✅ Saved 5m data to nifty50_intraday_data/BAJFINANCE_5m.csv
# 📥 Downloading 10m data for BAJFINANCE (3 days)...
# ✅ Saved 10m data to nifty50_intraday_data/BAJFINANCE_10m.csv
# 📥 Downloading 15m data for BAJFINANCE (3 days)...
# ✅ Saved 15m data to nifty50_intraday_data/BAJFINANCE_15m.csv
# 📥 Downloading 30m data for BAJFINANCE (3 days)...
# ✅ Saved 30m data to nifty50_intraday_data/BAJFINANCE_30m.csv
# 📥 Downloading 1h data for BAJFINANCE (5 days)...
# ✅ Saved 1h data to nifty50_intraday_data/BAJFINANCE_1h.csv
# 📥 Downloading 1m data for BAJAJFINSV (3 days)...
# ✅ Saved 1m data to nifty50_intraday_data/BAJAJFINSV_1m.csv
# 📥 Downloading 3m data for BAJAJFINSV (3 days)...
# ✅ Saved 3m data to nifty50_intraday_data/BAJAJFINSV_3m.csv
# 📥 Downloading 5m data for BAJAJFINSV (3 days)...
# ✅ Saved 5m data to nifty50_intraday_data/BAJAJFINSV_5m.csv
# 📥 Downloading 10m data for BAJAJFINSV (3 days)...
# ✅ Saved 10m data to nifty50_intraday_data/BAJAJFINSV_10m.csv
# 📥 Downloading 15m data for BAJAJFINSV (3 days)...
# ✅ Saved 15m data to nifty50_intraday_data/BAJAJFINSV_15m.csv
# 📥 Downloading 30m data for BAJAJFINSV (3 days)...
# ✅ Saved 30m data to nifty50_intraday_data/BAJAJFINSV_30m.csv
# 📥 Downloading 1h data for BAJAJFINSV (5 days)...
# ✅ Saved 1h data to nifty50_intraday_data/BAJAJFINSV_1h.csv
# 📥 Downloading 1m data for BEL (3 days)...
# ✅ Saved 1m data to nifty50_intraday_data/BEL_1m.csv
# 📥 Downloading 3m data for BEL (3 days)...
# ✅ Saved 3m data to nifty50_intraday_data/BEL_3m.csv
# 📥 Downloading 5m data for BEL (3 days)...
# ✅ Saved 5m data to nifty50_intraday_data/BEL_5m.csv
# 📥 Downloading 10m data for BEL (3 days)...
# ✅ Saved 10m data to nifty50_intraday_data/BEL_10m.csv
# 📥 Downloading 15m data for BEL (3 days)...
# ✅ Saved 15m data to nifty50_intraday_data/BEL_15m.csv
# 📥 Downloading 30m data for BEL (3 days)...
# ✅ Saved 30m data to nifty50_intraday_data/BEL_30m.csv
# 📥 Downloading 1h data for BEL (5 days)...
# ✅ Saved 1h data to nifty50_intraday_data/BEL_1h.csv
# 📥 Downloading 1m data for BHARTIARTL (3 days)...
# ✅ Saved 1m data to nifty50_intraday_data/BHARTIARTL_1m.csv
# 📥 Downloading 3m data for BHARTIARTL (3 days)...
# ✅ Saved 3m data to nifty50_intraday_data/BHARTIARTL_3m.csv
# 📥 Downloading 5m data for BHARTIARTL (3 days)...
# ✅ Saved 5m data to nifty50_intraday_data/BHARTIARTL_5m.csv
# 📥 Downloading 10m data for BHARTIARTL (3 days)...
# ✅ Saved 10m data to nifty50_intraday_data/BHARTIARTL_10m.csv
# 📥 Downloading 15m data for BHARTIARTL (3 days)...
# ✅ Saved 15m data to nifty50_intraday_data/BHARTIARTL_15m.csv
# 📥 Downloading 30m data for BHARTIARTL (3 days)...
# ✅ Saved 30m data to nifty50_intraday_data/BHARTIARTL_30m.csv
# 📥 Downloading 1h data for BHARTIARTL (5 days)...
# ✅ Saved 1h data to nifty50_intraday_data/BHARTIARTL_1h.csv
# 📥 Downloading 1m data for CIPLA (3 days)...
# ✅ Saved 1m data to nifty50_intraday_data/CIPLA_1m.csv
# 📥 Downloading 3m data for CIPLA (3 days)...
# ✅ Saved 3m data to nifty50_intraday_data/CIPLA_3m.csv
# 📥 Downloading 5m data for CIPLA (3 days)...
# ✅ Saved 5m data to nifty50_intraday_data/CIPLA_5m.csv
# 📥 Downloading 10m data for CIPLA (3 days)...
# ✅ Saved 10m data to nifty50_intraday_data/CIPLA_10m.csv
# 📥 Downloading 15m data for CIPLA (3 days)...
# ✅ Saved 15m data to nifty50_intraday_data/CIPLA_15m.csv
# 📥 Downloading 30m data for CIPLA (3 days)...
# ✅ Saved 30m data to nifty50_intraday_data/CIPLA_30m.csv
# 📥 Downloading 1h data for CIPLA (5 days)...
# ✅ Saved 1h data to nifty50_intraday_data/CIPLA_1h.csv
# 📥 Downloading 1m data for COALINDIA (3 days)...
# ✅ Saved 1m data to nifty50_intraday_data/COALINDIA_1m.csv
# 📥 Downloading 3m data for COALINDIA (3 days)...
# ✅ Saved 3m data to nifty50_intraday_data/COALINDIA_3m.csv
# 📥 Downloading 5m data for COALINDIA (3 days)...
# ✅ Saved 5m data to nifty50_intraday_data/COALINDIA_5m.csv
# 📥 Downloading 10m data for COALINDIA (3 days)...
# ✅ Saved 10m data to nifty50_intraday_data/COALINDIA_10m.csv
# 📥 Downloading 15m data for COALINDIA (3 days)...
# ✅ Saved 15m data to nifty50_intraday_data/COALINDIA_15m.csv
# 📥 Downloading 30m data for COALINDIA (3 days)...
# ✅ Saved 30m data to nifty50_intraday_data/COALINDIA_30m.csv
# 📥 Downloading 1h data for COALINDIA (5 days)...
# ✅ Saved 1h data to nifty50_intraday_data/COALINDIA_1h.csv
# 📥 Downloading 1m data for DRREDDY (3 days)...
# ✅ Saved 1m data to nifty50_intraday_data/DRREDDY_1m.csv
# 📥 Downloading 3m data for DRREDDY (3 days)...
# ✅ Saved 3m data to nifty50_intraday_data/DRREDDY_3m.csv
# 📥 Downloading 5m data for DRREDDY (3 days)...
# ✅ Saved 5m data to nifty50_intraday_data/DRREDDY_5m.csv
# 📥 Downloading 10m data for DRREDDY (3 days)...
# ✅ Saved 10m data to nifty50_intraday_data/DRREDDY_10m.csv
# 📥 Downloading 15m data for DRREDDY (3 days)...
# ✅ Saved 15m data to nifty50_intraday_data/DRREDDY_15m.csv
# 📥 Downloading 30m data for DRREDDY (3 days)...
# ✅ Saved 30m data to nifty50_intraday_data/DRREDDY_30m.csv
# 📥 Downloading 1h data for DRREDDY (5 days)...
# ✅ Saved 1h data to nifty50_intraday_data/DRREDDY_1h.csv
# 📥 Downloading 1m data for EICHERMOT (3 days)...
# ✅ Saved 1m data to nifty50_intraday_data/EICHERMOT_1m.csv
# 📥 Downloading 3m data for EICHERMOT (3 days)...
# ✅ Saved 3m data to nifty50_intraday_data/EICHERMOT_3m.csv
# 📥 Downloading 5m data for EICHERMOT (3 days)...
# ✅ Saved 5m data to nifty50_intraday_data/EICHERMOT_5m.csv
# 📥 Downloading 10m data for EICHERMOT (3 days)...
# ✅ Saved 10m data to nifty50_intraday_data/EICHERMOT_10m.csv
# 📥 Downloading 15m data for EICHERMOT (3 days)...
# ✅ Saved 15m data to nifty50_intraday_data/EICHERMOT_15m.csv
# 📥 Downloading 30m data for EICHERMOT (3 days)...
# ✅ Saved 30m data to nifty50_intraday_data/EICHERMOT_30m.csv
# 📥 Downloading 1h data for EICHERMOT (5 days)...
# ✅ Saved 1h data to nifty50_intraday_data/EICHERMOT_1h.csv
# 📥 Downloading 1m data for GRASIM (3 days)...
# ✅ Saved 1m data to nifty50_intraday_data/GRASIM_1m.csv
# 📥 Downloading 3m data for GRASIM (3 days)...
# ✅ Saved 3m data to nifty50_intraday_data/GRASIM_3m.csv
# 📥 Downloading 5m data for GRASIM (3 days)...
# ✅ Saved 5m data to nifty50_intraday_data/GRASIM_5m.csv
# 📥 Downloading 10m data for GRASIM (3 days)...
# ✅ Saved 10m data to nifty50_intraday_data/GRASIM_10m.csv
# 📥 Downloading 15m data for GRASIM (3 days)...
# ✅ Saved 15m data to nifty50_intraday_data/GRASIM_15m.csv
# 📥 Downloading 30m data for GRASIM (3 days)...
# ✅ Saved 30m data to nifty50_intraday_data/GRASIM_30m.csv
# 📥 Downloading 1h data for GRASIM (5 days)...
# ✅ Saved 1h data to nifty50_intraday_data/GRASIM_1h.csv
# 📥 Downloading 1m data for HCLTECH (3 days)...
# ✅ Saved 1m data to nifty50_intraday_data/HCLTECH_1m.csv
# 📥 Downloading 3m data for HCLTECH (3 days)...
# ✅ Saved 3m data to nifty50_intraday_data/HCLTECH_3m.csv
# 📥 Downloading 5m data for HCLTECH (3 days)...
# ✅ Saved 5m data to nifty50_intraday_data/HCLTECH_5m.csv
# 📥 Downloading 10m data for HCLTECH (3 days)...
# ✅ Saved 10m data to nifty50_intraday_data/HCLTECH_10m.csv
# 📥 Downloading 15m data for HCLTECH (3 days)...
# ✅ Saved 15m data to nifty50_intraday_data/HCLTECH_15m.csv
# 📥 Downloading 30m data for HCLTECH (3 days)...
# ✅ Saved 30m data to nifty50_intraday_data/HCLTECH_30m.csv
# 📥 Downloading 1h data for HCLTECH (5 days)...
# ✅ Saved 1h data to nifty50_intraday_data/HCLTECH_1h.csv
# 📥 Downloading 1m data for HDFCBANK (3 days)...
# ✅ Saved 1m data to nifty50_intraday_data/HDFCBANK_1m.csv
# 📥 Downloading 3m data for HDFCBANK (3 days)...
# ✅ Saved 3m data to nifty50_intraday_data/HDFCBANK_3m.csv
# 📥 Downloading 5m data for HDFCBANK (3 days)...
# ✅ Saved 5m data to nifty50_intraday_data/HDFCBANK_5m.csv
# 📥 Downloading 10m data for HDFCBANK (3 days)...
# ✅ Saved 10m data to nifty50_intraday_data/HDFCBANK_10m.csv
# 📥 Downloading 15m data for HDFCBANK (3 days)...
# ✅ Saved 15m data to nifty50_intraday_data/HDFCBANK_15m.csv
# 📥 Downloading 30m data for HDFCBANK (3 days)...
# ✅ Saved 30m data to nifty50_intraday_data/HDFCBANK_30m.csv
# 📥 Downloading 1h data for HDFCBANK (5 days)...
# ✅ Saved 1h data to nifty50_intraday_data/HDFCBANK_1h.csv
# 📥 Downloading 1m data for HDFCLIFE (3 days)...
# ✅ Saved 1m data to nifty50_intraday_data/HDFCLIFE_1m.csv
# 📥 Downloading 3m data for HDFCLIFE (3 days)...
# ✅ Saved 3m data to nifty50_intraday_data/HDFCLIFE_3m.csv
# 📥 Downloading 5m data for HDFCLIFE (3 days)...
# ✅ Saved 5m data to nifty50_intraday_data/HDFCLIFE_5m.csv
# 📥 Downloading 10m data for HDFCLIFE (3 days)...
# ✅ Saved 10m data to nifty50_intraday_data/HDFCLIFE_10m.csv
# 📥 Downloading 15m data for HDFCLIFE (3 days)...
# ✅ Saved 15m data to nifty50_intraday_data/HDFCLIFE_15m.csv
# 📥 Downloading 30m data for HDFCLIFE (3 days)...
# ✅ Saved 30m data to nifty50_intraday_data/HDFCLIFE_30m.csv
# 📥 Downloading 1h data for HDFCLIFE (5 days)...
# ✅ Saved 1h data to nifty50_intraday_data/HDFCLIFE_1h.csv
# 📥 Downloading 1m data for HEROMOTOCO (3 days)...
# ✅ Saved 1m data to nifty50_intraday_data/HEROMOTOCO_1m.csv
# 📥 Downloading 3m data for HEROMOTOCO (3 days)...
# ✅ Saved 3m data to nifty50_intraday_data/HEROMOTOCO_3m.csv
# 📥 Downloading 5m data for HEROMOTOCO (3 days)...
# ✅ Saved 5m data to nifty50_intraday_data/HEROMOTOCO_5m.csv
# 📥 Downloading 10m data for HEROMOTOCO (3 days)...
# ✅ Saved 10m data to nifty50_intraday_data/HEROMOTOCO_10m.csv
# 📥 Downloading 15m data for HEROMOTOCO (3 days)...
# ✅ Saved 15m data to nifty50_intraday_data/HEROMOTOCO_15m.csv
# 📥 Downloading 30m data for HEROMOTOCO (3 days)...
# ✅ Saved 30m data to nifty50_intraday_data/HEROMOTOCO_30m.csv
# 📥 Downloading 1h data for HEROMOTOCO (5 days)...
# ✅ Saved 1h data to nifty50_intraday_data/HEROMOTOCO_1h.csv
# 📥 Downloading 1m data for HINDALCO (3 days)...
# ✅ Saved 1m data to nifty50_intraday_data/HINDALCO_1m.csv
# 📥 Downloading 3m data for HINDALCO (3 days)...
# ✅ Saved 3m data to nifty50_intraday_data/HINDALCO_3m.csv
# 📥 Downloading 5m data for HINDALCO (3 days)...
# ✅ Saved 5m data to nifty50_intraday_data/HINDALCO_5m.csv
# 📥 Downloading 10m data for HINDALCO (3 days)...
# ✅ Saved 10m data to nifty50_intraday_data/HINDALCO_10m.csv
# 📥 Downloading 15m data for HINDALCO (3 days)...
# ✅ Saved 15m data to nifty50_intraday_data/HINDALCO_15m.csv
# 📥 Downloading 30m data for HINDALCO (3 days)...
# ✅ Saved 30m data to nifty50_intraday_data/HINDALCO_30m.csv
# 📥 Downloading 1h data for HINDALCO (5 days)...
# ✅ Saved 1h data to nifty50_intraday_data/HINDALCO_1h.csv
# 📥 Downloading 1m data for HINDUNILVR (3 days)...
# ✅ Saved 1m data to nifty50_intraday_data/HINDUNILVR_1m.csv
# 📥 Downloading 3m data for HINDUNILVR (3 days)...
# ✅ Saved 3m data to nifty50_intraday_data/HINDUNILVR_3m.csv
# 📥 Downloading 5m data for HINDUNILVR (3 days)...
# ✅ Saved 5m data to nifty50_intraday_data/HINDUNILVR_5m.csv
# 📥 Downloading 10m data for HINDUNILVR (3 days)...
# ✅ Saved 10m data to nifty50_intraday_data/HINDUNILVR_10m.csv
# 📥 Downloading 15m data for HINDUNILVR (3 days)...
# ✅ Saved 15m data to nifty50_intraday_data/HINDUNILVR_15m.csv
# 📥 Downloading 30m data for HINDUNILVR (3 days)...
# ✅ Saved 30m data to nifty50_intraday_data/HINDUNILVR_30m.csv
# 📥 Downloading 1h data for HINDUNILVR (5 days)...
# ✅ Saved 1h data to nifty50_intraday_data/HINDUNILVR_1h.csv
# 📥 Downloading 1m data for ICICIBANK (3 days)...
# ✅ Saved 1m data to nifty50_intraday_data/ICICIBANK_1m.csv
# 📥 Downloading 3m data for ICICIBANK (3 days)...
# ✅ Saved 3m data to nifty50_intraday_data/ICICIBANK_3m.csv
# 📥 Downloading 5m data for ICICIBANK (3 days)...
# ✅ Saved 5m data to nifty50_intraday_data/ICICIBANK_5m.csv
# 📥 Downloading 10m data for ICICIBANK (3 days)...
# ✅ Saved 10m data to nifty50_intraday_data/ICICIBANK_10m.csv
# 📥 Downloading 15m data for ICICIBANK (3 days)...
# ✅ Saved 15m data to nifty50_intraday_data/ICICIBANK_15m.csv
# 📥 Downloading 30m data for ICICIBANK (3 days)...
# ✅ Saved 30m data to nifty50_intraday_data/ICICIBANK_30m.csv
# 📥 Downloading 1h data for ICICIBANK (5 days)...
# ✅ Saved 1h data to nifty50_intraday_data/ICICIBANK_1h.csv
# 📥 Downloading 1m data for ITC (3 days)...
# ✅ Saved 1m data to nifty50_intraday_data/ITC_1m.csv
# 📥 Downloading 3m data for ITC (3 days)...
# ✅ Saved 3m data to nifty50_intraday_data/ITC_3m.csv
# 📥 Downloading 5m data for ITC (3 days)...
# ✅ Saved 5m data to nifty50_intraday_data/ITC_5m.csv
# 📥 Downloading 10m data for ITC (3 days)...
# ✅ Saved 10m data to nifty50_intraday_data/ITC_10m.csv
# 📥 Downloading 15m data for ITC (3 days)...
# ✅ Saved 15m data to nifty50_intraday_data/ITC_15m.csv
# 📥 Downloading 30m data for ITC (3 days)...
# ✅ Saved 30m data to nifty50_intraday_data/ITC_30m.csv
# 📥 Downloading 1h data for ITC (5 days)...
# ✅ Saved 1h data to nifty50_intraday_data/ITC_1h.csv
# 📥 Downloading 1m data for INDUSINDBK (3 days)...
# ✅ Saved 1m data to nifty50_intraday_data/INDUSINDBK_1m.csv
# 📥 Downloading 3m data for INDUSINDBK (3 days)...
# ✅ Saved 3m data to nifty50_intraday_data/INDUSINDBK_3m.csv
# 📥 Downloading 5m data for INDUSINDBK (3 days)...
# ✅ Saved 5m data to nifty50_intraday_data/INDUSINDBK_5m.csv
# 📥 Downloading 10m data for INDUSINDBK (3 days)...
# ✅ Saved 10m data to nifty50_intraday_data/INDUSINDBK_10m.csv
# 📥 Downloading 15m data for INDUSINDBK (3 days)...
# ✅ Saved 15m data to nifty50_intraday_data/INDUSINDBK_15m.csv
# 📥 Downloading 30m data for INDUSINDBK (3 days)...
# ✅ Saved 30m data to nifty50_intraday_data/INDUSINDBK_30m.csv
# 📥 Downloading 1h data for INDUSINDBK (5 days)...
# ✅ Saved 1h data to nifty50_intraday_data/INDUSINDBK_1h.csv
# 📥 Downloading 1m data for INFY (3 days)...
# ✅ Saved 1m data to nifty50_intraday_data/INFY_1m.csv
# 📥 Downloading 3m data for INFY (3 days)...
# ✅ Saved 3m data to nifty50_intraday_data/INFY_3m.csv
# 📥 Downloading 5m data for INFY (3 days)...
# ✅ Saved 5m data to nifty50_intraday_data/INFY_5m.csv
# 📥 Downloading 10m data for INFY (3 days)...
# ✅ Saved 10m data to nifty50_intraday_data/INFY_10m.csv
# 📥 Downloading 15m data for INFY (3 days)...
# ✅ Saved 15m data to nifty50_intraday_data/INFY_15m.csv
# 📥 Downloading 30m data for INFY (3 days)...
# ✅ Saved 30m data to nifty50_intraday_data/INFY_30m.csv
# 📥 Downloading 1h data for INFY (5 days)...
# ✅ Saved 1h data to nifty50_intraday_data/INFY_1h.csv
# 📥 Downloading 1m data for JSWSTEEL (3 days)...
# ✅ Saved 1m data to nifty50_intraday_data/JSWSTEEL_1m.csv
# 📥 Downloading 3m data for JSWSTEEL (3 days)...
# ✅ Saved 3m data to nifty50_intraday_data/JSWSTEEL_3m.csv
# 📥 Downloading 5m data for JSWSTEEL (3 days)...
# ✅ Saved 5m data to nifty50_intraday_data/JSWSTEEL_5m.csv
# 📥 Downloading 10m data for JSWSTEEL (3 days)...
# ✅ Saved 10m data to nifty50_intraday_data/JSWSTEEL_10m.csv
# 📥 Downloading 15m data for JSWSTEEL (3 days)...
# ✅ Saved 15m data to nifty50_intraday_data/JSWSTEEL_15m.csv
# 📥 Downloading 30m data for JSWSTEEL (3 days)...
# ✅ Saved 30m data to nifty50_intraday_data/JSWSTEEL_30m.csv
# 📥 Downloading 1h data for JSWSTEEL (5 days)...
# ✅ Saved 1h data to nifty50_intraday_data/JSWSTEEL_1h.csv
# 📥 Downloading 1m data for JIOFIN (3 days)...
# ✅ Saved 1m data to nifty50_intraday_data/JIOFIN_1m.csv
# 📥 Downloading 3m data for JIOFIN (3 days)...
# ✅ Saved 3m data to nifty50_intraday_data/JIOFIN_3m.csv
# 📥 Downloading 5m data for JIOFIN (3 days)...
# ✅ Saved 5m data to nifty50_intraday_data/JIOFIN_5m.csv
# 📥 Downloading 10m data for JIOFIN (3 days)...
# ✅ Saved 10m data to nifty50_intraday_data/JIOFIN_10m.csv
# 📥 Downloading 15m data for JIOFIN (3 days)...
# ✅ Saved 15m data to nifty50_intraday_data/JIOFIN_15m.csv
# 📥 Downloading 30m data for JIOFIN (3 days)...
# ✅ Saved 30m data to nifty50_intraday_data/JIOFIN_30m.csv
# 📥 Downloading 1h data for JIOFIN (5 days)...
# ✅ Saved 1h data to nifty50_intraday_data/JIOFIN_1h.csv
# 📥 Downloading 1m data for KOTAKBANK (3 days)...
# ✅ Saved 1m data to nifty50_intraday_data/KOTAKBANK_1m.csv
# 📥 Downloading 3m data for KOTAKBANK (3 days)...
# ✅ Saved 3m data to nifty50_intraday_data/KOTAKBANK_3m.csv
# 📥 Downloading 5m data for KOTAKBANK (3 days)...
# ✅ Saved 5m data to nifty50_intraday_data/KOTAKBANK_5m.csv
# 📥 Downloading 10m data for KOTAKBANK (3 days)...
# ✅ Saved 10m data to nifty50_intraday_data/KOTAKBANK_10m.csv
# 📥 Downloading 15m data for KOTAKBANK (3 days)...
# ✅ Saved 15m data to nifty50_intraday_data/KOTAKBANK_15m.csv
# 📥 Downloading 30m data for KOTAKBANK (3 days)...
# ✅ Saved 30m data to nifty50_intraday_data/KOTAKBANK_30m.csv
# 📥 Downloading 1h data for KOTAKBANK (5 days)...
# ✅ Saved 1h data to nifty50_intraday_data/KOTAKBANK_1h.csv
# 📥 Downloading 1m data for LT (3 days)...
# ✅ Saved 1m data to nifty50_intraday_data/LT_1m.csv
# 📥 Downloading 3m data for LT (3 days)...
# ✅ Saved 3m data to nifty50_intraday_data/LT_3m.csv
# 📥 Downloading 5m data for LT (3 days)...
# ✅ Saved 5m data to nifty50_intraday_data/LT_5m.csv
# 📥 Downloading 10m data for LT (3 days)...
# ✅ Saved 10m data to nifty50_intraday_data/LT_10m.csv
# 📥 Downloading 15m data for LT (3 days)...
# ✅ Saved 15m data to nifty50_intraday_data/LT_15m.csv
# 📥 Downloading 30m data for LT (3 days)...
# ✅ Saved 30m data to nifty50_intraday_data/LT_30m.csv
# 📥 Downloading 1h data for LT (5 days)...
# ✅ Saved 1h data to nifty50_intraday_data/LT_1h.csv
# 📥 Downloading 1m data for M&M (3 days)...
# ✅ Saved 1m data to nifty50_intraday_data/M&M_1m.csv
# 📥 Downloading 3m data for M&M (3 days)...
# ✅ Saved 3m data to nifty50_intraday_data/M&M_3m.csv
# 📥 Downloading 5m data for M&M (3 days)...
# ✅ Saved 5m data to nifty50_intraday_data/M&M_5m.csv
# 📥 Downloading 10m data for M&M (3 days)...
# ✅ Saved 10m data to nifty50_intraday_data/M&M_10m.csv
# 📥 Downloading 15m data for M&M (3 days)...
# ✅ Saved 15m data to nifty50_intraday_data/M&M_15m.csv
# 📥 Downloading 30m data for M&M (3 days)...
# ✅ Saved 30m data to nifty50_intraday_data/M&M_30m.csv
# 📥 Downloading 1h data for M&M (5 days)...
# ✅ Saved 1h data to nifty50_intraday_data/M&M_1h.csv
# 📥 Downloading 1m data for MARUTI (3 days)...
# ✅ Saved 1m data to nifty50_intraday_data/MARUTI_1m.csv
# 📥 Downloading 3m data for MARUTI (3 days)...
# ✅ Saved 3m data to nifty50_intraday_data/MARUTI_3m.csv
# 📥 Downloading 5m data for MARUTI (3 days)...
# ✅ Saved 5m data to nifty50_intraday_data/MARUTI_5m.csv
# 📥 Downloading 10m data for MARUTI (3 days)...
# ✅ Saved 10m data to nifty50_intraday_data/MARUTI_10m.csv
# 📥 Downloading 15m data for MARUTI (3 days)...
# ✅ Saved 15m data to nifty50_intraday_data/MARUTI_15m.csv
# 📥 Downloading 30m data for MARUTI (3 days)...
# ✅ Saved 30m data to nifty50_intraday_data/MARUTI_30m.csv
# 📥 Downloading 1h data for MARUTI (5 days)...
# ✅ Saved 1h data to nifty50_intraday_data/MARUTI_1h.csv
# 📥 Downloading 1m data for NTPC (3 days)...
# ✅ Saved 1m data to nifty50_intraday_data/NTPC_1m.csv
# 📥 Downloading 3m data for NTPC (3 days)...
# ✅ Saved 3m data to nifty50_intraday_data/NTPC_3m.csv
# 📥 Downloading 5m data for NTPC (3 days)...
# ✅ Saved 5m data to nifty50_intraday_data/NTPC_5m.csv
# 📥 Downloading 10m data for NTPC (3 days)...
# ✅ Saved 10m data to nifty50_intraday_data/NTPC_10m.csv
# 📥 Downloading 15m data for NTPC (3 days)...
# ✅ Saved 15m data to nifty50_intraday_data/NTPC_15m.csv
# 📥 Downloading 30m data for NTPC (3 days)...
# ✅ Saved 30m data to nifty50_intraday_data/NTPC_30m.csv
# 📥 Downloading 1h data for NTPC (5 days)...
# ✅ Saved 1h data to nifty50_intraday_data/NTPC_1h.csv
# 📥 Downloading 1m data for NESTLEIND (3 days)...
# ✅ Saved 1m data to nifty50_intraday_data/NESTLEIND_1m.csv
# 📥 Downloading 3m data for NESTLEIND (3 days)...
# ✅ Saved 3m data to nifty50_intraday_data/NESTLEIND_3m.csv
# 📥 Downloading 5m data for NESTLEIND (3 days)...
# ✅ Saved 5m data to nifty50_intraday_data/NESTLEIND_5m.csv
# 📥 Downloading 10m data for NESTLEIND (3 days)...
# ✅ Saved 10m data to nifty50_intraday_data/NESTLEIND_10m.csv
# 📥 Downloading 15m data for NESTLEIND (3 days)...
# ✅ Saved 15m data to nifty50_intraday_data/NESTLEIND_15m.csv
# 📥 Downloading 30m data for NESTLEIND (3 days)...
# ✅ Saved 30m data to nifty50_intraday_data/NESTLEIND_30m.csv
# 📥 Downloading 1h data for NESTLEIND (5 days)...
# ✅ Saved 1h data to nifty50_intraday_data/NESTLEIND_1h.csv
# 📥 Downloading 1m data for ONGC (3 days)...
# ✅ Saved 1m data to nifty50_intraday_data/ONGC_1m.csv
# 📥 Downloading 3m data for ONGC (3 days)...
# ✅ Saved 3m data to nifty50_intraday_data/ONGC_3m.csv
# 📥 Downloading 5m data for ONGC (3 days)...
# ✅ Saved 5m data to nifty50_intraday_data/ONGC_5m.csv
# 📥 Downloading 10m data for ONGC (3 days)...
# ✅ Saved 10m data to nifty50_intraday_data/ONGC_10m.csv
# 📥 Downloading 15m data for ONGC (3 days)...
# ✅ Saved 15m data to nifty50_intraday_data/ONGC_15m.csv
# 📥 Downloading 30m data for ONGC (3 days)...
# ✅ Saved 30m data to nifty50_intraday_data/ONGC_30m.csv
# 📥 Downloading 1h data for ONGC (5 days)...
# ✅ Saved 1h data to nifty50_intraday_data/ONGC_1h.csv
# 📥 Downloading 1m data for POWERGRID (3 days)...
# ✅ Saved 1m data to nifty50_intraday_data/POWERGRID_1m.csv
# 📥 Downloading 3m data for POWERGRID (3 days)...
# ✅ Saved 3m data to nifty50_intraday_data/POWERGRID_3m.csv
# 📥 Downloading 5m data for POWERGRID (3 days)...
# ✅ Saved 5m data to nifty50_intraday_data/POWERGRID_5m.csv
# 📥 Downloading 10m data for POWERGRID (3 days)...
# ✅ Saved 10m data to nifty50_intraday_data/POWERGRID_10m.csv
# 📥 Downloading 15m data for POWERGRID (3 days)...
# ✅ Saved 15m data to nifty50_intraday_data/POWERGRID_15m.csv
# 📥 Downloading 30m data for POWERGRID (3 days)...
# ✅ Saved 30m data to nifty50_intraday_data/POWERGRID_30m.csv
# 📥 Downloading 1h data for POWERGRID (5 days)...
# ✅ Saved 1h data to nifty50_intraday_data/POWERGRID_1h.csv
# 📥 Downloading 1m data for RELIANCE (3 days)...
# ✅ Saved 1m data to nifty50_intraday_data/RELIANCE_1m.csv
# 📥 Downloading 3m data for RELIANCE (3 days)...
# ✅ Saved 3m data to nifty50_intraday_data/RELIANCE_3m.csv
# 📥 Downloading 5m data for RELIANCE (3 days)...
# ✅ Saved 5m data to nifty50_intraday_data/RELIANCE_5m.csv
# 📥 Downloading 10m data for RELIANCE (3 days)...
# ✅ Saved 10m data to nifty50_intraday_data/RELIANCE_10m.csv
# 📥 Downloading 15m data for RELIANCE (3 days)...
# ✅ Saved 15m data to nifty50_intraday_data/RELIANCE_15m.csv
# 📥 Downloading 30m data for RELIANCE (3 days)...
# ✅ Saved 30m data to nifty50_intraday_data/RELIANCE_30m.csv
# 📥 Downloading 1h data for RELIANCE (5 days)...
# ✅ Saved 1h data to nifty50_intraday_data/RELIANCE_1h.csv
# 📥 Downloading 1m data for SBILIFE (3 days)...
# ✅ Saved 1m data to nifty50_intraday_data/SBILIFE_1m.csv
# 📥 Downloading 3m data for SBILIFE (3 days)...
# ✅ Saved 3m data to nifty50_intraday_data/SBILIFE_3m.csv
# 📥 Downloading 5m data for SBILIFE (3 days)...
# ✅ Saved 5m data to nifty50_intraday_data/SBILIFE_5m.csv
# 📥 Downloading 10m data for SBILIFE (3 days)...
# ✅ Saved 10m data to nifty50_intraday_data/SBILIFE_10m.csv
# 📥 Downloading 15m data for SBILIFE (3 days)...
# ✅ Saved 15m data to nifty50_intraday_data/SBILIFE_15m.csv
# 📥 Downloading 30m data for SBILIFE (3 days)...
# ✅ Saved 30m data to nifty50_intraday_data/SBILIFE_30m.csv
# 📥 Downloading 1h data for SBILIFE (5 days)...
# ✅ Saved 1h data to nifty50_intraday_data/SBILIFE_1h.csv
# 📥 Downloading 1m data for SHRIRAMFIN (3 days)...
# ✅ Saved 1m data to nifty50_intraday_data/SHRIRAMFIN_1m.csv
# 📥 Downloading 3m data for SHRIRAMFIN (3 days)...
# ✅ Saved 3m data to nifty50_intraday_data/SHRIRAMFIN_3m.csv
# 📥 Downloading 5m data for SHRIRAMFIN (3 days)...
# ✅ Saved 5m data to nifty50_intraday_data/SHRIRAMFIN_5m.csv
# 📥 Downloading 10m data for SHRIRAMFIN (3 days)...
# ✅ Saved 10m data to nifty50_intraday_data/SHRIRAMFIN_10m.csv
# 📥 Downloading 15m data for SHRIRAMFIN (3 days)...
# ✅ Saved 15m data to nifty50_intraday_data/SHRIRAMFIN_15m.csv
# 📥 Downloading 30m data for SHRIRAMFIN (3 days)...
# ✅ Saved 30m data to nifty50_intraday_data/SHRIRAMFIN_30m.csv
# 📥 Downloading 1h data for SHRIRAMFIN (5 days)...
# ✅ Saved 1h data to nifty50_intraday_data/SHRIRAMFIN_1h.csv
# 📥 Downloading 1m data for SBIN (3 days)...
# ✅ Saved 1m data to nifty50_intraday_data/SBIN_1m.csv
# 📥 Downloading 3m data for SBIN (3 days)...
# ✅ Saved 3m data to nifty50_intraday_data/SBIN_3m.csv
# 📥 Downloading 5m data for SBIN (3 days)...
# ✅ Saved 5m data to nifty50_intraday_data/SBIN_5m.csv
# 📥 Downloading 10m data for SBIN (3 days)...
# ✅ Saved 10m data to nifty50_intraday_data/SBIN_10m.csv
# 📥 Downloading 15m data for SBIN (3 days)...
# ✅ Saved 15m data to nifty50_intraday_data/SBIN_15m.csv
# 📥 Downloading 30m data for SBIN (3 days)...
# ✅ Saved 30m data to nifty50_intraday_data/SBIN_30m.csv
# 📥 Downloading 1h data for SBIN (5 days)...
# ✅ Saved 1h data to nifty50_intraday_data/SBIN_1h.csv
# 📥 Downloading 1m data for SUNPHARMA (3 days)...
# ✅ Saved 1m data to nifty50_intraday_data/SUNPHARMA_1m.csv
# 📥 Downloading 3m data for SUNPHARMA (3 days)...
# ✅ Saved 3m data to nifty50_intraday_data/SUNPHARMA_3m.csv
# 📥 Downloading 5m data for SUNPHARMA (3 days)...
# ✅ Saved 5m data to nifty50_intraday_data/SUNPHARMA_5m.csv
# 📥 Downloading 10m data for SUNPHARMA (3 days)...
# ✅ Saved 10m data to nifty50_intraday_data/SUNPHARMA_10m.csv
# 📥 Downloading 15m data for SUNPHARMA (3 days)...
# ✅ Saved 15m data to nifty50_intraday_data/SUNPHARMA_15m.csv
# 📥 Downloading 30m data for SUNPHARMA (3 days)...
# ✅ Saved 30m data to nifty50_intraday_data/SUNPHARMA_30m.csv
# 📥 Downloading 1h data for SUNPHARMA (5 days)...
# ✅ Saved 1h data to nifty50_intraday_data/SUNPHARMA_1h.csv
# 📥 Downloading 1m data for TCS (3 days)...
# ✅ Saved 1m data to nifty50_intraday_data/TCS_1m.csv
# 📥 Downloading 3m data for TCS (3 days)...
# ✅ Saved 3m data to nifty50_intraday_data/TCS_3m.csv
# 📥 Downloading 5m data for TCS (3 days)...
# ✅ Saved 5m data to nifty50_intraday_data/TCS_5m.csv
# 📥 Downloading 10m data for TCS (3 days)...
# ✅ Saved 10m data to nifty50_intraday_data/TCS_10m.csv
# 📥 Downloading 15m data for TCS (3 days)...
# ✅ Saved 15m data to nifty50_intraday_data/TCS_15m.csv
# 📥 Downloading 30m data for TCS (3 days)...
# ✅ Saved 30m data to nifty50_intraday_data/TCS_30m.csv
# 📥 Downloading 1h data for TCS (5 days)...
# ✅ Saved 1h data to nifty50_intraday_data/TCS_1h.csv
# 📥 Downloading 1m data for TATACONSUM (3 days)...
# ✅ Saved 1m data to nifty50_intraday_data/TATACONSUM_1m.csv
# 📥 Downloading 3m data for TATACONSUM (3 days)...
# ✅ Saved 3m data to nifty50_intraday_data/TATACONSUM_3m.csv
# 📥 Downloading 5m data for TATACONSUM (3 days)...
# ✅ Saved 5m data to nifty50_intraday_data/TATACONSUM_5m.csv
# 📥 Downloading 10m data for TATACONSUM (3 days)...
# ✅ Saved 10m data to nifty50_intraday_data/TATACONSUM_10m.csv
# 📥 Downloading 15m data for TATACONSUM (3 days)...
# ✅ Saved 15m data to nifty50_intraday_data/TATACONSUM_15m.csv
# 📥 Downloading 30m data for TATACONSUM (3 days)...
# ✅ Saved 30m data to nifty50_intraday_data/TATACONSUM_30m.csv
# 📥 Downloading 1h data for TATACONSUM (5 days)...
# ✅ Saved 1h data to nifty50_intraday_data/TATACONSUM_1h.csv
# 📥 Downloading 1m data for TATAMOTORS (3 days)...
# ✅ Saved 1m data to nifty50_intraday_data/TATAMOTORS_1m.csv
# 📥 Downloading 3m data for TATAMOTORS (3 days)...
# ✅ Saved 3m data to nifty50_intraday_data/TATAMOTORS_3m.csv
# 📥 Downloading 5m data for TATAMOTORS (3 days)...
# ✅ Saved 5m data to nifty50_intraday_data/TATAMOTORS_5m.csv
# 📥 Downloading 10m data for TATAMOTORS (3 days)...
# ✅ Saved 10m data to nifty50_intraday_data/TATAMOTORS_10m.csv
# 📥 Downloading 15m data for TATAMOTORS (3 days)...
# ✅ Saved 15m data to nifty50_intraday_data/TATAMOTORS_15m.csv
# 📥 Downloading 30m data for TATAMOTORS (3 days)...
# ✅ Saved 30m data to nifty50_intraday_data/TATAMOTORS_30m.csv
# 📥 Downloading 1h data for TATAMOTORS (5 days)...
# ✅ Saved 1h data to nifty50_intraday_data/TATAMOTORS_1h.csv
# 📥 Downloading 1m data for TATASTEEL (3 days)...
# ✅ Saved 1m data to nifty50_intraday_data/TATASTEEL_1m.csv
# 📥 Downloading 3m data for TATASTEEL (3 days)...
# ✅ Saved 3m data to nifty50_intraday_data/TATASTEEL_3m.csv
# 📥 Downloading 5m data for TATASTEEL (3 days)...
# ✅ Saved 5m data to nifty50_intraday_data/TATASTEEL_5m.csv
# 📥 Downloading 10m data for TATASTEEL (3 days)...
# ✅ Saved 10m data to nifty50_intraday_data/TATASTEEL_10m.csv
# 📥 Downloading 15m data for TATASTEEL (3 days)...
# ✅ Saved 15m data to nifty50_intraday_data/TATASTEEL_15m.csv
# 📥 Downloading 30m data for TATASTEEL (3 days)...
# ✅ Saved 30m data to nifty50_intraday_data/TATASTEEL_30m.csv
# 📥 Downloading 1h data for TATASTEEL (5 days)...
# ✅ Saved 1h data to nifty50_intraday_data/TATASTEEL_1h.csv
# 📥 Downloading 1m data for TECHM (3 days)...
# ✅ Saved 1m data to nifty50_intraday_data/TECHM_1m.csv
# 📥 Downloading 3m data for TECHM (3 days)...
# ✅ Saved 3m data to nifty50_intraday_data/TECHM_3m.csv
# 📥 Downloading 5m data for TECHM (3 days)...
# ✅ Saved 5m data to nifty50_intraday_data/TECHM_5m.csv
# 📥 Downloading 10m data for TECHM (3 days)...
# ✅ Saved 10m data to nifty50_intraday_data/TECHM_10m.csv
# 📥 Downloading 15m data for TECHM (3 days)...
# ✅ Saved 15m data to nifty50_intraday_data/TECHM_15m.csv
# 📥 Downloading 30m data for TECHM (3 days)...
# ✅ Saved 30m data to nifty50_intraday_data/TECHM_30m.csv
# 📥 Downloading 1h data for TECHM (5 days)...
# ✅ Saved 1h data to nifty50_intraday_data/TECHM_1h.csv
# 📥 Downloading 1m data for TITAN (3 days)...
# ✅ Saved 1m data to nifty50_intraday_data/TITAN_1m.csv
# 📥 Downloading 3m data for TITAN (3 days)...
# ✅ Saved 3m data to nifty50_intraday_data/TITAN_3m.csv
# 📥 Downloading 5m data for TITAN (3 days)...
# ✅ Saved 5m data to nifty50_intraday_data/TITAN_5m.csv
# 📥 Downloading 10m data for TITAN (3 days)...
# ✅ Saved 10m data to nifty50_intraday_data/TITAN_10m.csv
# 📥 Downloading 15m data for TITAN (3 days)...
# ✅ Saved 15m data to nifty50_intraday_data/TITAN_15m.csv
# 📥 Downloading 30m data for TITAN (3 days)...
# ✅ Saved 30m data to nifty50_intraday_data/TITAN_30m.csv
# 📥 Downloading 1h data for TITAN (5 days)...
# ✅ Saved 1h data to nifty50_intraday_data/TITAN_1h.csv
# 📥 Downloading 1m data for TRENT (3 days)...
# ✅ Saved 1m data to nifty50_intraday_data/TRENT_1m.csv
# 📥 Downloading 3m data for TRENT (3 days)...
# ✅ Saved 3m data to nifty50_intraday_data/TRENT_3m.csv
# 📥 Downloading 5m data for TRENT (3 days)...
# ✅ Saved 5m data to nifty50_intraday_data/TRENT_5m.csv
# 📥 Downloading 10m data for TRENT (3 days)...
# ✅ Saved 10m data to nifty50_intraday_data/TRENT_10m.csv
# 📥 Downloading 15m data for TRENT (3 days)...
# ✅ Saved 15m data to nifty50_intraday_data/TRENT_15m.csv
# 📥 Downloading 30m data for TRENT (3 days)...
# ✅ Saved 30m data to nifty50_intraday_data/TRENT_30m.csv
# 📥 Downloading 1h data for TRENT (5 days)...
# ✅ Saved 1h data to nifty50_intraday_data/TRENT_1h.csv
# 📥 Downloading 1m data for ULTRACEMCO (3 days)...
# ✅ Saved 1m data to nifty50_intraday_data/ULTRACEMCO_1m.csv
# 📥 Downloading 3m data for ULTRACEMCO (3 days)...
# ✅ Saved 3m data to nifty50_intraday_data/ULTRACEMCO_3m.csv
# 📥 Downloading 5m data for ULTRACEMCO (3 days)...
# ✅ Saved 5m data to nifty50_intraday_data/ULTRACEMCO_5m.csv
# 📥 Downloading 10m data for ULTRACEMCO (3 days)...
# ✅ Saved 10m data to nifty50_intraday_data/ULTRACEMCO_10m.csv
# 📥 Downloading 15m data for ULTRACEMCO (3 days)...
# ✅ Saved 15m data to nifty50_intraday_data/ULTRACEMCO_15m.csv
# 📥 Downloading 30m data for ULTRACEMCO (3 days)...
# ✅ Saved 30m data to nifty50_intraday_data/ULTRACEMCO_30m.csv
# 📥 Downloading 1h data for ULTRACEMCO (5 days)...
# ✅ Saved 1h data to nifty50_intraday_data/ULTRACEMCO_1h.csv
# 📥 Downloading 1m data for WIPRO (3 days)...
# ✅ Saved 1m data to nifty50_intraday_data/WIPRO_1m.csv
# 📥 Downloading 3m data for WIPRO (3 days)...
# ✅ Saved 3m data to nifty50_intraday_data/WIPRO_3m.csv
# 📥 Downloading 5m data for WIPRO (3 days)...
# ✅ Saved 5m data to nifty50_intraday_data/WIPRO_5m.csv
# 📥 Downloading 10m data for WIPRO (3 days)...
# ✅ Saved 10m data to nifty50_intraday_data/WIPRO_10m.csv
# 📥 Downloading 15m data for WIPRO (3 days)...
# ✅ Saved 15m data to nifty50_intraday_data/WIPRO_15m.csv
# 📥 Downloading 30m data for WIPRO (3 days)...
# ✅ Saved 30m data to nifty50_intraday_data/WIPRO_30m.csv
# 📥 Downloading 1h data for WIPRO (5 days)...
# ✅ Saved 1h data to nifty50_intraday_data/WIPRO_1h.csv
# 📥 Downloading 1m data for ZOMATO (3 days)...
# ✅ Saved 1m data to nifty50_intraday_data/ZOMATO_1m.csv
# 📥 Downloading 3m data for ZOMATO (3 days)...
# ✅ Saved 3m data to nifty50_intraday_data/ZOMATO_3m.csv
# 📥 Downloading 5m data for ZOMATO (3 days)...
# ✅ Saved 5m data to nifty50_intraday_data/ZOMATO_5m.csv
# 📥 Downloading 10m data for ZOMATO (3 days)...
# ✅ Saved 10m data to nifty50_intraday_data/ZOMATO_10m.csv
# 📥 Downloading 15m data for ZOMATO (3 days)...
# ✅ Saved 15m data to nifty50_intraday_data/ZOMATO_15m.csv
# 📥 Downloading 30m data for ZOMATO (3 days)...
# ✅ Saved 30m data to nifty50_intraday_data/ZOMATO_30m.csv
# 📥 Downloading 1h data for ZOMATO (5 days)...
# ✅ Saved 1h data to nifty50_intraday_data/ZOMATO_1h.csv
#
# ✅ All intraday data downloaded successfully!
