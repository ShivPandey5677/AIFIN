# %%
import pandas as pd
def get_dataframes():
    df=pd.read_csv('long_term_dataset.csv')
    symbol_dfs={Symbol:group for Symbol,group in df.groupby('Symbol')}
    return symbol_dfs

# %%
symbol_dfs=get_dataframes()
for symbol, symbol_df in symbol_dfs.items():
    print(f"Symbol: {symbol}, Rows: {len(symbol_df)}")
# Out:
# Symbol: 360ONE.NS, Rows: 869
# Symbol: AAVAS.NS, Rows: 1100
# Symbol: ABBOTINDIA.NS, Rows: 1967
# Symbol: ABCAPITAL.NS, Rows: 1372
# Symbol: ABSLAMC.NS, Rows: 358
# Symbol: ACC.NS, Rows: 1967
# Symbol: ADANIENT.NS, Rows: 1967
# Symbol: ADANIGREEN.NS, Rows: 1175
# Symbol: ADANIPOWER.NS, Rows: 1967
# Symbol: AFFLE.NS, Rows: 895
# Symbol: AJANTPHARM.NS, Rows: 1967
# Symbol: ALKEM.NS, Rows: 1789
# Symbol: ALOKINDS.NS, Rows: 1967
# Symbol: AMBER.NS, Rows: 1269
# Symbol: AMBUJACEM.NS, Rows: 1967
# Symbol: ANANDRATHI.NS, Rows: 315
# Symbol: ANGELONE.NS, Rows: 611
# Symbol: APLLTD.NS, Rows: 1967
# Symbol: APOLLOHOSP.NS, Rows: 1967
# Symbol: APOLLOTYRE.NS, Rows: 1967
# Symbol: APTUS.NS, Rows: 391
# Symbol: ASAHIINDIA.NS, Rows: 1967
# Symbol: ASIANPAINT.NS, Rows: 1967
# Symbol: ASTERDM.NS, Rows: 1251
# Symbol: ASTRAZEN.NS, Rows: 1967
# Symbol: ATGL.NS, Rows: 1081
# Symbol: AUBANK.NS, Rows: 1408
# Symbol: AUROPHARMA.NS, Rows: 1967
# Symbol: AXISBANK.NS, Rows: 1967
# Symbol: BAJAJ-AUTO.NS, Rows: 1967
# Symbol: BAJAJFINSV.NS, Rows: 1967
# Symbol: BAJAJHLDNG.NS, Rows: 1967
# Symbol: BAJFINANCE.NS, Rows: 1967
# Symbol: BALKRISIND.NS, Rows: 1967
# Symbol: BANDHANBNK.NS, Rows: 1231
# Symbol: BANKBARODA.NS, Rows: 1967
# Symbol: BANKINDIA.NS, Rows: 1967
# Symbol: BATAINDIA.NS, Rows: 1967
# Symbol: BERGEPAINT.NS, Rows: 1967
# Symbol: BHARATFORG.NS, Rows: 1967
# Symbol: BIOCON.NS, Rows: 1967
# Symbol: BIRLACORPN.NS, Rows: 734
# Symbol: BLUESTARCO.NS, Rows: 1967
# Symbol: BOSCHLTD.NS, Rows: 1967
# Symbol: BPCL.NS, Rows: 1967
# Symbol: BSE.NS, Rows: 1514
# Symbol: BSOFT.NS, Rows: 1967
# Symbol: CAMPUS.NS, Rows: 217
# Symbol: CAMS.NS, Rows: 611
# Symbol: CANBK.NS, Rows: 1967
# Symbol: CANFINHOME.NS, Rows: 1967
# Symbol: CAPLIPOINT.NS, Rows: 1967
# Symbol: CASTROLIND.NS, Rows: 1967
# Symbol: CDSL.NS, Rows: 1415
# Symbol: CEATLTD.NS, Rows: 1967
# Symbol: CENTRALBK.NS, Rows: 1967
# Symbol: CENTURYPLY.NS, Rows: 1967
# Symbol: CERA.NS, Rows: 1967
# Symbol: CESC.NS, Rows: 1967
# Symbol: CGCL.NS, Rows: 1967
# Symbol: CHENNPETRO.NS, Rows: 1967
# Symbol: CHOLAFIN.NS, Rows: 1967
# Symbol: CHOLAHLDNG.NS, Rows: 1967
# Symbol: CIEINDIA.NS, Rows: 735
# Symbol: CIPLA.NS, Rows: 1967
# Symbol: COALINDIA.NS, Rows: 1967
# Symbol: COFORGE.NS, Rows: 1967
# Symbol: CRAFTSMAN.NS, Rows: 492
# Symbol: CREDITACC.NS, Rows: 734
# Symbol: CRISIL.NS, Rows: 1967
# Symbol: CROMPTON.NS, Rows: 1695
# Symbol: CUB.NS, Rows: 1967
# Symbol: CYIENT.NS, Rows: 1967
# Symbol: DALBHARAT.NS, Rows: 1049
# Symbol: DIVISLAB.NS, Rows: 1967
# Symbol: DIXON.NS, Rows: 1361
# Symbol: DRREDDY.NS, Rows: 1967
# Symbol: EICHERMOT.NS, Rows: 1967
# Symbol: ENDURANCE.NS, Rows: 1588
# Symbol: EQUITASBNK.NS, Rows: 569
# Symbol: ERIS.NS, Rows: 1415
# Symbol: EXIDEIND.NS, Rows: 1967
# Symbol: FORTIS.NS, Rows: 1967
# Symbol: GAIL.NS, Rows: 1967
# Symbol: GLAND.NS, Rows: 577
# Symbol: GLAXO.NS, Rows: 1967
# Symbol: GLENMARK.NS, Rows: 1967
# Symbol: GMDCLTD.NS, Rows: 1967
# Symbol: GRANULES.NS, Rows: 1967
# Symbol: GRASIM.NS, Rows: 1967
# Symbol: GRAVITA.NS, Rows: 1967
# Symbol: GSPL.NS, Rows: 1967
# Symbol: GUJGASLTD.NS, Rows: 1853
# Symbol: HAPPSTMNDS.NS, Rows: 622
# Symbol: HAVELLS.NS, Rows: 1967
# Symbol: HCLTECH.NS, Rows: 1967
# Symbol: HEROMOTOCO.NS, Rows: 1967
# Symbol: HINDALCO.NS, Rows: 1967
# Symbol: HINDCOPPER.NS, Rows: 1967
# Symbol: HINDPETRO.NS, Rows: 1967
# Symbol: HINDZINC.NS, Rows: 1967
# Symbol: IGL.NS, Rows: 1967
# Symbol: INDIACEM.NS, Rows: 1967
# Symbol: INFY.NS, Rows: 1967
# Symbol: INTELLECT.NS, Rows: 1967
# Symbol: IOC.NS, Rows: 1967
# Symbol: JBMA.NS, Rows: 1967
# Symbol: JINDALSTEL.NS, Rows: 1967
# Symbol: JKCEMENT.NS, Rows: 1967
# Symbol: JKLAKSHMI.NS, Rows: 734
# Symbol: JKTYRE.NS, Rows: 1967
# Symbol: JPPOWER.NS, Rows: 1967
# Symbol: JSL.NS, Rows: 1967
# Symbol: JSWENERGY.NS, Rows: 1967
# Symbol: JSWSTEEL.NS, Rows: 1967
# Symbol: KAJARIACER.NS, Rows: 1967
# Symbol: KALYANKJIL.NS, Rows: 491
# Symbol: KANSAINER.NS, Rows: 1967
# Symbol: KPITTECH.NS, Rows: 970
# Symbol: KPRMILL.NS, Rows: 1967
# Symbol: LALPATHLAB.NS, Rows: 1789
# Symbol: LATENTVIEW.NS, Rows: 330
# Symbol: LTIM.NS, Rows: 1647
# Symbol: LTTS.NS, Rows: 1604
# Symbol: M&M.NS, Rows: 1967
# Symbol: MAHABANK.NS, Rows: 1967
# Symbol: MAPMYINDIA.NS, Rows: 310
# Symbol: MARUTI.NS, Rows: 1967
# Symbol: MASTEK.NS, Rows: 1967
# Symbol: MEDANTA.NS, Rows: 84
# Symbol: MGL.NS, Rows: 1660
# Symbol: MINDACORP.NS, Rows: 1967
# Symbol: MPHASIS.NS, Rows: 1967
# Symbol: MRF.NS, Rows: 1967
# Symbol: MRPL.NS, Rows: 1967
# Symbol: NATIONALUM.NS, Rows: 1967
# Symbol: NAVA.NS, Rows: 1967
# Symbol: NEWGEN.NS, Rows: 1270
# Symbol: NHPC.NS, Rows: 1967
# Symbol: NLCINDIA.NS, Rows: 1967
# Symbol: NMDC.NS, Rows: 735
# Symbol: NSLNISP.NS, Rows: 19
# Symbol: NTPC.NS, Rows: 1967
# Symbol: NUVOCO.NS, Rows: 369
# Symbol: OFSS.NS, Rows: 1967
# Symbol: OIL.NS, Rows: 1967
# Symbol: ONGC.NS, Rows: 1967
# Symbol: PAGEIND.NS, Rows: 1967
# Symbol: PERSISTENT.NS, Rows: 1967
# Symbol: PETRONET.NS, Rows: 1967
# Symbol: PGEL.NS, Rows: 1967
# Symbol: POWERGRID.NS, Rows: 1967
# Symbol: RAMCOCEM.NS, Rows: 1967
# Symbol: RELIANCE.NS, Rows: 1967
# Symbol: RPOWER.NS, Rows: 1967
# Symbol: SAIL.NS, Rows: 1967
# Symbol: SARDAEN.NS, Rows: 1967
# Symbol: SHREECEM.NS, Rows: 1967
# Symbol: SJVN.NS, Rows: 735
# Symbol: SONATSOFTW.NS, Rows: 1967
# Symbol: TANLA.NS, Rows: 1967
# Symbol: TATAELXSI.NS, Rows: 1967
# Symbol: TATAPOWER.NS, Rows: 735
# Symbol: TATASTEEL.NS, Rows: 1967
# Symbol: TCS.NS, Rows: 1967
# Symbol: TECHM.NS, Rows: 735
# Symbol: TORNTPOWER.NS, Rows: 735
# Symbol: TRIDENT.NS, Rows: 1967
# Symbol: ULTRACEMCO.NS, Rows: 1967
# Symbol: VEDL.NS, Rows: 1967
# Symbol: VTL.NS, Rows: 1967
# Symbol: WELSPUNLIV.NS, Rows: 1967
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 4
#       2 for symbol, symbol_df in symbol_dfs.items():
#       3     print(f"Symbol: {symbol}, Rows: {len(symbol_df)}")
# ----> 4 print(symbol_dfs.len())
#
# AttributeError: 'dict' object has no attribute 'len'

# %%
symbol_dfs['360ONE.NS'].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 869 entries, 0 to 868
# Data columns (total 97 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Date                       869 non-null    object
#  1   Symbol                     869 non-null    object
#  2   Open                       869 non-null    float64
#  3   Close_Today                869 non-null    float64
#  4   Close_After_Year           869 non-null    float64
#  5   Target_Return              869 non-null    float64
#  6   High                       869 non-null    float64
#  7   Low                        869 non-null    float64
#  8   Volume                     869 non-null    int64
#  9   Dividends                  869 non-null    float64
#  10  Stock Splits               869 non-null    float64
#  11  volume_adi                 869 non-null    float64
#  12  volume_obv                 869 non-null    int64
#  13  volume_cmf                 869 non-null    float64
#  14  volume_fi                  869 non-null    float64
#  15  volume_em                  869 non-null    float64
#  16  volume_sma_em              869 non-null    float64
#  17  volume_vpt                 869 non-null    float64
#  18  volume_vwap                869 non-null    float64
#  19  volume_mfi                 869 non-null    float64
#  20  volume_nvi                 869 non-null    float64
#  21  volatility_bbm             869 non-null    float64
#  22  volatility_bbh             869 non-null    float64
#  23  volatility_bbl             869 non-null    float64
#  24  volatility_bbw             869 non-null    float64
#  25  volatility_bbp             869 non-null    float64
#  26  volatility_bbhi            869 non-null    float64
#  27  volatility_bbli            869 non-null    float64
#  28  volatility_kcc             869 non-null    float64
#  29  volatility_kch             869 non-null    float64
#  30  volatility_kcl             869 non-null    float64
#  31  volatility_kcw             869 non-null    float64
#  32  volatility_kcp             869 non-null    float64
#  33  volatility_kchi            869 non-null    float64
#  34  volatility_kcli            869 non-null    float64
#  35  volatility_dcl             869 non-null    float64
#  36  volatility_dch             869 non-null    float64
#  37  volatility_dcm             869 non-null    float64
#  38  volatility_dcw             869 non-null    float64
#  39  volatility_dcp             869 non-null    float64
#  40  volatility_atr             869 non-null    float64
#  41  volatility_ui              869 non-null    float64
#  42  trend_macd                 869 non-null    float64
#  43  trend_macd_signal          869 non-null    float64
#  44  trend_macd_diff            869 non-null    float64
#  45  trend_sma_fast             869 non-null    float64
#  46  trend_sma_slow             869 non-null    float64
#  47  trend_ema_fast             869 non-null    float64
#  48  trend_ema_slow             869 non-null    float64
#  49  trend_vortex_ind_pos       869 non-null    float64
#  50  trend_vortex_ind_neg       869 non-null    float64
#  51  trend_vortex_ind_diff      869 non-null    float64
#  52  trend_trix                 869 non-null    float64
#  53  trend_mass_index           869 non-null    float64
#  54  trend_dpo                  869 non-null    float64
#  55  trend_kst                  869 non-null    float64
#  56  trend_kst_sig              869 non-null    float64
#  57  trend_kst_diff             869 non-null    float64
#  58  trend_ichimoku_conv        869 non-null    float64
#  59  trend_ichimoku_base        869 non-null    float64
#  60  trend_ichimoku_a           869 non-null    float64
#  61  trend_ichimoku_b           869 non-null    float64
#  62  trend_stc                  869 non-null    float64
#  63  trend_adx                  869 non-null    float64
#  64  trend_adx_pos              869 non-null    float64
#  65  trend_adx_neg              869 non-null    float64
#  66  trend_cci                  869 non-null    float64
#  67  trend_visual_ichimoku_a    869 non-null    float64
#  68  trend_visual_ichimoku_b    869 non-null    float64
#  69  trend_aroon_up             869 non-null    float64
#  70  trend_aroon_down           869 non-null    float64
#  71  trend_aroon_ind            869 non-null    float64
#  72  trend_psar_up              869 non-null    float64
#  73  trend_psar_down            869 non-null    float64
#  74  trend_psar_up_indicator    869 non-null    float64
#  75  trend_psar_down_indicator  869 non-null    float64
#  76  momentum_rsi               869 non-null    float64
#  77  momentum_stoch_rsi         869 non-null    float64
#  78  momentum_stoch_rsi_k       869 non-null    float64
#  79  momentum_stoch_rsi_d       869 non-null    float64
#  80  momentum_tsi               869 non-null    float64
#  81  momentum_uo                869 non-null    float64
#  82  momentum_stoch             869 non-null    float64
#  83  momentum_stoch_signal      869 non-null    float64
#  84  momentum_wr                869 non-null    float64
#  85  momentum_ao                869 non-null    float64
#  86  momentum_roc               869 non-null    float64
#  87  momentum_ppo               869 non-null    float64
#  88  momentum_ppo_signal        869 non-null    float64
#  89  momentum_ppo_hist          869 non-null    float64
#  90  momentum_pvo               869 non-null    float64
#  91  momentum_pvo_signal        869 non-null    float64
#  92  momentum_pvo_hist          869 non-null    float64
#  93  momentum_kama              869 non-null    float64
#  94  others_dr                  869 non-null    float64
#  95  others_dlr                 869 non-null    float64
#  96  others_cr                  869 non-null    float64
# dtypes: float64(93), int64(2), object(2)
# memory usage: 665.3+ KB

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

def split_data(df, test_size=0.15, val_size=0.15, target_col='Target_Return'):
    # Extract features and target
    feature_cols = df.columns.difference(['Date', 'Symbol', 'Target_Return', 'Close_After_Year', 'Close_Today'])
    X = df[feature_cols]
    y = df[target_col]

    # First split to get test set
    X_temp, X_test, y_temp, y_test = train_test_split(X, y, test_size=test_size, shuffle=False)

    # Then split remaining into train/val
    val_ratio = val_size / (1 - test_size)
    X_train, X_val, y_train, y_val = train_test_split(X_temp, y_temp, test_size=val_ratio, shuffle=False)

    return X_train, X_val, X_test, y_train, y_val, y_test, feature_cols

def select_best_features(X_train, X_val, y_train, y_val, feature_cols, max_features=20):
    rf = RandomForestRegressor(n_estimators=100, random_state=42)
    rf.fit(X_train, y_train)

    feature_importances = pd.Series(rf.feature_importances_, index=feature_cols)
    top_features = feature_importances.sort_values(ascending=False).head(max_features).index.tolist()

    # Evaluate performance using top features
    rf_top = RandomForestRegressor(n_estimators=100, random_state=42)
    rf_top.fit(X_train[top_features], y_train)
    y_pred = rf_top.predict(X_val[top_features])
    val_loss = mean_squared_error(y_val, y_pred)

    return top_features, val_loss

def process_all_symbols(symbol_dfs, max_features=20):
    results = {}

    for symbol, df in symbol_dfs.items():
        try:
            X_train, X_val, X_test, y_train, y_val, y_test, feature_cols = split_data(df)
            top_feats, loss = select_best_features(X_train, X_val, y_train, y_val, feature_cols, max_features=max_features)
            results[symbol] = {
                'top_features': top_feats,
                'val_loss': loss
            }
            print(f"✅ {symbol}: Top {len(top_feats)} features, Validation MSE = {loss:.5f}")
        except Exception as e:
            print(f"❌ Error processing {symbol}: {e}")

    return results

# %%
symbol_dfs = get_dataframes()  # From your previous step
selection_results = process_all_symbols(symbol_dfs, max_features=25)

# Save selected features to JSON
import json
with open("selected_features.json", "w") as f:
    json.dump(selection_results, f, indent=4)
# Out:
# ✅ 360ONE.NS: Top 25 features, Validation MSE = 0.29933
# ✅ AAVAS.NS: Top 25 features, Validation MSE = 0.10463
# ✅ ABBOTINDIA.NS: Top 25 features, Validation MSE = 0.05632
# ✅ ABCAPITAL.NS: Top 25 features, Validation MSE = 0.18189
# ✅ ABSLAMC.NS: Top 25 features, Validation MSE = 0.01431
# ✅ ACC.NS: Top 25 features, Validation MSE = 0.04069
# ✅ ADANIENT.NS: Top 25 features, Validation MSE = 2.16738
# ✅ ADANIGREEN.NS: Top 25 features, Validation MSE = 1.97732
# ✅ ADANIPOWER.NS: Top 25 features, Validation MSE = 2.38758
# ✅ AFFLE.NS: Top 25 features, Validation MSE = 0.05693
# ✅ AJANTPHARM.NS: Top 25 features, Validation MSE = 0.18707
# ✅ ALKEM.NS: Top 25 features, Validation MSE = 0.15899
# ✅ ALOKINDS.NS: Top 25 features, Validation MSE = 0.18408
# ✅ AMBER.NS: Top 25 features, Validation MSE = 1.38475
# ✅ AMBUJACEM.NS: Top 25 features, Validation MSE = 0.56507
# ✅ ANANDRATHI.NS: Top 25 features, Validation MSE = 0.27023
# ✅ ANGELONE.NS: Top 25 features, Validation MSE = 0.98454
# ✅ APLLTD.NS: Top 25 features, Validation MSE = 0.11431
# ✅ APOLLOHOSP.NS: Top 25 features, Validation MSE = 0.03562
# ✅ APOLLOTYRE.NS: Top 25 features, Validation MSE = 0.63727
# ✅ APTUS.NS: Top 25 features, Validation MSE = 0.03004
# ✅ ASAHIINDIA.NS: Top 25 features, Validation MSE = 0.35926
# ✅ ASIANPAINT.NS: Top 25 features, Validation MSE = 0.01882
# ✅ ASTERDM.NS: Top 25 features, Validation MSE = 0.18300
# ✅ ASTRAZEN.NS: Top 25 features, Validation MSE = 0.14241
# ✅ ATGL.NS: Top 25 features, Validation MSE = 0.62233
# ✅ AUBANK.NS: Top 25 features, Validation MSE = 0.02057
# ✅ AUROPHARMA.NS: Top 25 features, Validation MSE = 0.66139
# ✅ AXISBANK.NS: Top 25 features, Validation MSE = 0.04712
# ✅ BAJAJ-AUTO.NS: Top 25 features, Validation MSE = 0.17914
# ✅ BAJAJFINSV.NS: Top 25 features, Validation MSE = 1.32904
# ✅ BAJAJHLDNG.NS: Top 25 features, Validation MSE = 0.14802
# ✅ BAJFINANCE.NS: Top 25 features, Validation MSE = 0.05067
# ✅ BALKRISIND.NS: Top 25 features, Validation MSE = 0.13168
# ✅ BANDHANBNK.NS: Top 25 features, Validation MSE = 0.01755
# ✅ BANKBARODA.NS: Top 25 features, Validation MSE = 0.18484
# ✅ BANKINDIA.NS: Top 25 features, Validation MSE = 0.57676
# ✅ BATAINDIA.NS: Top 25 features, Validation MSE = 0.17835
# ✅ BERGEPAINT.NS: Top 25 features, Validation MSE = 0.06170
# ✅ BHARATFORG.NS: Top 25 features, Validation MSE = 0.06033
# ✅ BIOCON.NS: Top 25 features, Validation MSE = 0.03059
# ✅ BIRLACORPN.NS: Top 25 features, Validation MSE = 0.12857
# ✅ BLUESTARCO.NS: Top 25 features, Validation MSE = 0.10522
# ✅ BOSCHLTD.NS: Top 25 features, Validation MSE = 0.03591
# ✅ BPCL.NS: Top 25 features, Validation MSE = 0.03245
# ✅ BSE.NS: Top 25 features, Validation MSE = 9.93327
# ✅ BSOFT.NS: Top 25 features, Validation MSE = 1.12255
# ✅ CAMPUS.NS: Top 25 features, Validation MSE = 0.00518
# ✅ CAMS.NS: Top 25 features, Validation MSE = 0.05525
# ✅ CANBK.NS: Top 25 features, Validation MSE = 0.05313
# ✅ CANFINHOME.NS: Top 25 features, Validation MSE = 0.27542
# ✅ CAPLIPOINT.NS: Top 25 features, Validation MSE = 0.23500
# ✅ CASTROLIND.NS: Top 25 features, Validation MSE = 0.10174
# ✅ CDSL.NS: Top 25 features, Validation MSE = 0.67568
# ✅ CEATLTD.NS: Top 25 features, Validation MSE = 0.17832
# ✅ CENTRALBK.NS: Top 25 features, Validation MSE = 0.60748
# ✅ CENTURYPLY.NS: Top 25 features, Validation MSE = 0.05156
# ✅ CERA.NS: Top 25 features, Validation MSE = 0.19349
# ✅ CESC.NS: Top 25 features, Validation MSE = 0.11226
# ✅ CGCL.NS: Top 25 features, Validation MSE = 0.88178
# ✅ CHENNPETRO.NS: Top 25 features, Validation MSE = 1.29228
# ✅ CHOLAFIN.NS: Top 25 features, Validation MSE = 0.54715
# ✅ CHOLAHLDNG.NS: Top 25 features, Validation MSE = 0.28246
# ✅ CIEINDIA.NS: Top 25 features, Validation MSE = 0.05108
# ✅ CIPLA.NS: Top 25 features, Validation MSE = 0.02410
# ✅ COALINDIA.NS: Top 25 features, Validation MSE = 0.07778
# ✅ COFORGE.NS: Top 25 features, Validation MSE = 0.32973
# ✅ CRAFTSMAN.NS: Top 25 features, Validation MSE = 0.03261
# ✅ CREDITACC.NS: Top 25 features, Validation MSE = 0.26272
# ✅ CRISIL.NS: Top 25 features, Validation MSE = 0.04470
# ✅ CROMPTON.NS: Top 25 features, Validation MSE = 0.00542
# ✅ CUB.NS: Top 25 features, Validation MSE = 0.04439
# ✅ CYIENT.NS: Top 25 features, Validation MSE = 0.33617
# ✅ DALBHARAT.NS: Top 25 features, Validation MSE = 0.16323
# ✅ DIVISLAB.NS: Top 25 features, Validation MSE = 0.06229
# ✅ DIXON.NS: Top 25 features, Validation MSE = 1.64581
# ✅ DRREDDY.NS: Top 25 features, Validation MSE = 0.06321
# ✅ EICHERMOT.NS: Top 25 features, Validation MSE = 0.02314
# ✅ ENDURANCE.NS: Top 25 features, Validation MSE = 0.04261
# ✅ EQUITASBNK.NS: Top 25 features, Validation MSE = 0.10668
# ✅ ERIS.NS: Top 25 features, Validation MSE = 0.14979
# ✅ EXIDEIND.NS: Top 25 features, Validation MSE = 0.34477
# ✅ FORTIS.NS: Top 25 features, Validation MSE = 0.02752
# ✅ GAIL.NS: Top 25 features, Validation MSE = 0.16041
# ✅ GLAND.NS: Top 25 features, Validation MSE = 0.09536
# ✅ GLAXO.NS: Top 25 features, Validation MSE = 0.04598
# ✅ GLENMARK.NS: Top 25 features, Validation MSE = 0.57710
# ✅ GMDCLTD.NS: Top 25 features, Validation MSE = 0.90808
# ✅ GRANULES.NS: Top 25 features, Validation MSE = 0.02120
# ✅ GRASIM.NS: Top 25 features, Validation MSE = 0.05125
# ✅ GRAVITA.NS: Top 25 features, Validation MSE = 0.45054
# ✅ GSPL.NS: Top 25 features, Validation MSE = 0.10050
# ✅ GUJGASLTD.NS: Top 25 features, Validation MSE = 0.04628
# ✅ HAPPSTMNDS.NS: Top 25 features, Validation MSE = 0.00945
# ✅ HAVELLS.NS: Top 25 features, Validation MSE = 0.37923
# ✅ HCLTECH.NS: Top 25 features, Validation MSE = 0.08827
# ✅ HEROMOTOCO.NS: Top 25 features, Validation MSE = 0.05970
# ✅ HINDALCO.NS: Top 25 features, Validation MSE = 0.03296
# ✅ HINDCOPPER.NS: Top 25 features, Validation MSE = 0.20478
# ✅ HINDPETRO.NS: Top 25 features, Validation MSE = 0.17379
# ✅ HINDZINC.NS: Top 25 features, Validation MSE = 0.22631
# ✅ IGL.NS: Top 25 features, Validation MSE = 0.23830
# ✅ INDIACEM.NS: Top 25 features, Validation MSE = 0.03275
# ✅ INFY.NS: Top 25 features, Validation MSE = 0.00739
# ✅ INTELLECT.NS: Top 25 features, Validation MSE = 10.14334
# ✅ IOC.NS: Top 25 features, Validation MSE = 0.04189
# ✅ JBMA.NS: Top 25 features, Validation MSE = 2.96224
# ✅ JINDALSTEL.NS: Top 25 features, Validation MSE = 0.44680
# ✅ JKCEMENT.NS: Top 25 features, Validation MSE = 0.18787
# ✅ JKLAKSHMI.NS: Top 25 features, Validation MSE = 0.05914
# ✅ JKTYRE.NS: Top 25 features, Validation MSE = 0.76300
# ✅ JPPOWER.NS: Top 25 features, Validation MSE = 0.64618
# ✅ JSL.NS: Top 25 features, Validation MSE = 3.03813
# ✅ JSWENERGY.NS: Top 25 features, Validation MSE = 12.47464
# ✅ JSWSTEEL.NS: Top 25 features, Validation MSE = 0.03921
# ✅ KAJARIACER.NS: Top 25 features, Validation MSE = 0.04912
# ✅ KALYANKJIL.NS: Top 25 features, Validation MSE = 0.41612
# ✅ KANSAINER.NS: Top 25 features, Validation MSE = 0.03606
# ✅ KPITTECH.NS: Top 25 features, Validation MSE = 0.20804
# ✅ KPRMILL.NS: Top 25 features, Validation MSE = 1.92449
# ✅ LALPATHLAB.NS: Top 25 features, Validation MSE = 0.07104
# ✅ LATENTVIEW.NS: Top 25 features, Validation MSE = 0.00787
# ✅ LTIM.NS: Top 25 features, Validation MSE = 0.19200
# ✅ LTTS.NS: Top 25 features, Validation MSE = 0.33678
# ✅ M&M.NS: Top 25 features, Validation MSE = 0.04835
# ✅ MAHABANK.NS: Top 25 features, Validation MSE = 0.41349
# ✅ MAPMYINDIA.NS: Top 25 features, Validation MSE = 0.09056
# ✅ MARUTI.NS: Top 25 features, Validation MSE = 0.00659
# ✅ MASTEK.NS: Top 25 features, Validation MSE = 0.31586
# ✅ MEDANTA.NS: Top 25 features, Validation MSE = 0.01076
# ✅ MGL.NS: Top 25 features, Validation MSE = 0.09491
# ✅ MINDACORP.NS: Top 25 features, Validation MSE = 0.22416
# ✅ MPHASIS.NS: Top 25 features, Validation MSE = 0.13524
# ✅ MRF.NS: Top 25 features, Validation MSE = 0.09692
# ✅ MRPL.NS: Top 25 features, Validation MSE = 0.31109
# ✅ NATIONALUM.NS: Top 25 features, Validation MSE = 0.31724
# ✅ NAVA.NS: Top 25 features, Validation MSE = 0.10090
# ✅ NEWGEN.NS: Top 25 features, Validation MSE = 2.73553
# ✅ NHPC.NS: Top 25 features, Validation MSE = 0.05931
# ✅ NLCINDIA.NS: Top 25 features, Validation MSE = 0.48914
# ✅ NMDC.NS: Top 25 features, Validation MSE = 0.48401
# ✅ NSLNISP.NS: Top 25 features, Validation MSE = 0.00151
# ✅ NTPC.NS: Top 25 features, Validation MSE = 0.05100
# ✅ NUVOCO.NS: Top 25 features, Validation MSE = 0.00150
# ✅ OFSS.NS: Top 25 features, Validation MSE = 0.31398
# ✅ OIL.NS: Top 25 features, Validation MSE = 0.20626
# ✅ ONGC.NS: Top 25 features, Validation MSE = 0.06143
# ✅ PAGEIND.NS: Top 25 features, Validation MSE = 0.11368
# ✅ PERSISTENT.NS: Top 25 features, Validation MSE = 0.13705
# ✅ PETRONET.NS: Top 25 features, Validation MSE = 0.01940
# ✅ PGEL.NS: Top 25 features, Validation MSE = 0.28118
# ✅ POWERGRID.NS: Top 25 features, Validation MSE = 0.03083
# ✅ RAMCOCEM.NS: Top 25 features, Validation MSE = 0.14001
# ✅ RELIANCE.NS: Top 25 features, Validation MSE = 0.01415
# ✅ RPOWER.NS: Top 25 features, Validation MSE = 0.29741
# ✅ SAIL.NS: Top 25 features, Validation MSE = 0.09826
# ✅ SARDAEN.NS: Top 25 features, Validation MSE = 0.96310
# ✅ SHREECEM.NS: Top 25 features, Validation MSE = 0.10131
# ✅ SJVN.NS: Top 25 features, Validation MSE = 0.62898
# ✅ SONATSOFTW.NS: Top 25 features, Validation MSE = 0.38037
# ✅ TANLA.NS: Top 25 features, Validation MSE = 0.23689
# ✅ TATAELXSI.NS: Top 25 features, Validation MSE = 0.43029
# ✅ TATAPOWER.NS: Top 25 features, Validation MSE = 0.03597
# ✅ TATASTEEL.NS: Top 25 features, Validation MSE = 1.94821
# ✅ TCS.NS: Top 25 features, Validation MSE = 0.02035
# ✅ TECHM.NS: Top 25 features, Validation MSE = 0.02714
# ✅ TORNTPOWER.NS: Top 25 features, Validation MSE = 0.54375
# ✅ TRIDENT.NS: Top 25 features, Validation MSE = 0.15226
# ✅ ULTRACEMCO.NS: Top 25 features, Validation MSE = 0.09256
# ✅ VEDL.NS: Top 25 features, Validation MSE = 0.08434
# ✅ VTL.NS: Top 25 features, Validation MSE = 0.14072
# ✅ WELSPUNLIV.NS: Top 25 features, Validation MSE = 0.52779
