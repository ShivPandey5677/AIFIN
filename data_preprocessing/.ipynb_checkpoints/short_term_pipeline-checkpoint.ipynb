# %%
import os
import pandas as pd
from utils import add_technical_indicators

def load_processed_symbols(log_path):
    if os.path.exists(log_path):
        with open(log_path, "r") as f:
            return set(line.strip() for line in f.readlines())
    return set()

def log_processed_symbol(log_path, filename):
    with open(log_path, "a") as f:
        f.write(filename + "\n")

def process_short_term_data(input_folder, output_folder):
    os.makedirs(output_folder, exist_ok=True)
    all_files = [f for f in os.listdir(input_folder) if f.endswith(".csv")]

    for file in all_files:
        timeframe = file.split("_")[-1].replace(".csv", "")
        log_file_path = os.path.join(output_folder, f"{timeframe}_processed.txt")
        processed = load_processed_symbols(log_file_path)

        if file in processed:
            print(f"⏩ Skipping {file} (already processed)")
            continue

        try:
            df = pd.read_csv(os.path.join(input_folder, file), parse_dates=["Timestamp"])
            df = df.sort_values("Timestamp").reset_index(drop=True)

            # ✅ Skip if too few rows
            if len(df) < 15:
                print(f"⚠️ Skipping {file}: only {len(df)} rows (needs at least 15)")
                continue

            df_ta = add_technical_indicators(df.copy())
            output_path = os.path.join(output_folder, file)
            df_ta.to_csv(output_path, index=False)

            log_processed_symbol(log_file_path, file)
            print(f"✅ Processed and saved {file}")
        except Exception as e:
            print(f"❌ Error processing {file}: {e}")

# %%
process_short_term_data(input_folder="../data/short_term_data/nifty50_intraday_data",output_folder="../data/short_term_data/nifty50_intraday_data1")
# Out:
# ✅ Processed and saved ADANIENT_10m.csv
# ✅ Processed and saved ADANIENT_15m.csv
# ❌ Error processing ADANIENT_1h.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved ADANIENT_1m.csv
# ❌ Error processing ADANIENT_30m.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved ADANIENT_3m.csv
# ✅ Processed and saved ADANIENT_5m.csv
# ✅ Processed and saved ADANIPORTS_10m.csv
# ✅ Processed and saved ADANIPORTS_15m.csv
# ❌ Error processing ADANIPORTS_1h.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved ADANIPORTS_1m.csv
# ❌ Error processing ADANIPORTS_30m.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved ADANIPORTS_3m.csv
# ✅ Processed and saved ADANIPORTS_5m.csv
# ✅ Processed and saved APOLLOHOSP_10m.csv
# ✅ Processed and saved APOLLOHOSP_15m.csv
# ❌ Error processing APOLLOHOSP_1h.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved APOLLOHOSP_1m.csv
# ❌ Error processing APOLLOHOSP_30m.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved APOLLOHOSP_3m.csv
# ✅ Processed and saved APOLLOHOSP_5m.csv
# ✅ Processed and saved ASIANPAINT_10m.csv
# ✅ Processed and saved ASIANPAINT_15m.csv
# ❌ Error processing ASIANPAINT_1h.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved ASIANPAINT_1m.csv
# ❌ Error processing ASIANPAINT_30m.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved ASIANPAINT_3m.csv
# ✅ Processed and saved ASIANPAINT_5m.csv
# ✅ Processed and saved AXISBANK_10m.csv
# ✅ Processed and saved AXISBANK_15m.csv
# ❌ Error processing AXISBANK_1h.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved AXISBANK_1m.csv
# ❌ Error processing AXISBANK_30m.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved AXISBANK_3m.csv
# ✅ Processed and saved AXISBANK_5m.csv
# ✅ Processed and saved BAJAJ-AUTO_10m.csv
# ✅ Processed and saved BAJAJ-AUTO_15m.csv
# ❌ Error processing BAJAJ-AUTO_1h.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved BAJAJ-AUTO_1m.csv
# ❌ Error processing BAJAJ-AUTO_30m.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved BAJAJ-AUTO_3m.csv
# ✅ Processed and saved BAJAJ-AUTO_5m.csv
# ✅ Processed and saved BAJAJFINSV_10m.csv
# ✅ Processed and saved BAJAJFINSV_15m.csv
# ❌ Error processing BAJAJFINSV_1h.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved BAJAJFINSV_1m.csv
# ❌ Error processing BAJAJFINSV_30m.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved BAJAJFINSV_3m.csv
# ✅ Processed and saved BAJAJFINSV_5m.csv
# ✅ Processed and saved BAJFINANCE_10m.csv
# ✅ Processed and saved BAJFINANCE_15m.csv
# ❌ Error processing BAJFINANCE_1h.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved BAJFINANCE_1m.csv
# ❌ Error processing BAJFINANCE_30m.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved BAJFINANCE_3m.csv
# ✅ Processed and saved BAJFINANCE_5m.csv
# ✅ Processed and saved BEL_10m.csv
# ✅ Processed and saved BEL_15m.csv
# ❌ Error processing BEL_1h.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved BEL_1m.csv
# ❌ Error processing BEL_30m.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved BEL_3m.csv
# ✅ Processed and saved BEL_5m.csv
# ✅ Processed and saved BHARTIARTL_10m.csv
# ✅ Processed and saved BHARTIARTL_15m.csv
# ❌ Error processing BHARTIARTL_1h.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved BHARTIARTL_1m.csv
# ❌ Error processing BHARTIARTL_30m.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved BHARTIARTL_3m.csv
# ✅ Processed and saved BHARTIARTL_5m.csv
# ✅ Processed and saved BPCL_10m.csv
# ✅ Processed and saved BPCL_15m.csv
# ❌ Error processing BPCL_1h.csv: index 14 is out of bounds for axis 0 with size 6
# ✅ Processed and saved BPCL_1m.csv
# ❌ Error processing BPCL_30m.csv: index 14 is out of bounds for axis 0 with size 12
# ✅ Processed and saved BPCL_3m.csv
# ✅ Processed and saved BPCL_5m.csv
# ✅ Processed and saved BRITANNIA_10m.csv
# ✅ Processed and saved BRITANNIA_15m.csv
# ❌ Error processing BRITANNIA_1h.csv: index 14 is out of bounds for axis 0 with size 6
# ✅ Processed and saved BRITANNIA_1m.csv
# ❌ Error processing BRITANNIA_30m.csv: index 14 is out of bounds for axis 0 with size 12
# ✅ Processed and saved BRITANNIA_3m.csv
# ✅ Processed and saved BRITANNIA_5m.csv
# ✅ Processed and saved CIPLA_10m.csv
# ✅ Processed and saved CIPLA_15m.csv
# ❌ Error processing CIPLA_1h.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved CIPLA_1m.csv
# ❌ Error processing CIPLA_30m.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved CIPLA_3m.csv
# ✅ Processed and saved CIPLA_5m.csv
# ✅ Processed and saved COALINDIA_10m.csv
# ✅ Processed and saved COALINDIA_15m.csv
# ❌ Error processing COALINDIA_1h.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved COALINDIA_1m.csv
# ❌ Error processing COALINDIA_30m.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved COALINDIA_3m.csv
# ✅ Processed and saved COALINDIA_5m.csv
# ✅ Processed and saved DRREDDY_10m.csv
# ✅ Processed and saved DRREDDY_15m.csv
# ❌ Error processing DRREDDY_1h.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved DRREDDY_1m.csv
# ❌ Error processing DRREDDY_30m.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved DRREDDY_3m.csv
# ✅ Processed and saved DRREDDY_5m.csv
# ✅ Processed and saved EICHERMOT_10m.csv
# ✅ Processed and saved EICHERMOT_15m.csv
# ❌ Error processing EICHERMOT_1h.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved EICHERMOT_1m.csv
# ❌ Error processing EICHERMOT_30m.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved EICHERMOT_3m.csv
# ✅ Processed and saved EICHERMOT_5m.csv
# ✅ Processed and saved GRASIM_10m.csv
# ✅ Processed and saved GRASIM_15m.csv
# ❌ Error processing GRASIM_1h.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved GRASIM_1m.csv
# ❌ Error processing GRASIM_30m.csv: index 14 is out of bounds for axis 0 with size 12
# ✅ Processed and saved GRASIM_3m.csv
# ✅ Processed and saved GRASIM_5m.csv
# ✅ Processed and saved HCLTECH_10m.csv
# ✅ Processed and saved HCLTECH_15m.csv
# ❌ Error processing HCLTECH_1h.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved HCLTECH_1m.csv
# ❌ Error processing HCLTECH_30m.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved HCLTECH_3m.csv
# ✅ Processed and saved HCLTECH_5m.csv
# ✅ Processed and saved HDFCBANK_10m.csv
# ✅ Processed and saved HDFCBANK_15m.csv
# ❌ Error processing HDFCBANK_1h.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved HDFCBANK_1m.csv
# ❌ Error processing HDFCBANK_30m.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved HDFCBANK_3m.csv
# ✅ Processed and saved HDFCBANK_5m.csv
# ✅ Processed and saved HDFCLIFE_10m.csv
# ✅ Processed and saved HDFCLIFE_15m.csv
# ❌ Error processing HDFCLIFE_1h.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved HDFCLIFE_1m.csv
# ❌ Error processing HDFCLIFE_30m.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved HDFCLIFE_3m.csv
# ✅ Processed and saved HDFCLIFE_5m.csv
# ✅ Processed and saved HEROMOTOCO_10m.csv
# ✅ Processed and saved HEROMOTOCO_15m.csv
# ❌ Error processing HEROMOTOCO_1h.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved HEROMOTOCO_1m.csv
# ❌ Error processing HEROMOTOCO_30m.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved HEROMOTOCO_3m.csv
# ✅ Processed and saved HEROMOTOCO_5m.csv
# ✅ Processed and saved HINDALCO_10m.csv
# ✅ Processed and saved HINDALCO_15m.csv
# ❌ Error processing HINDALCO_1h.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved HINDALCO_1m.csv
# ❌ Error processing HINDALCO_30m.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved HINDALCO_3m.csv
# ✅ Processed and saved HINDALCO_5m.csv
# ✅ Processed and saved HINDUNILVR_10m.csv
# ✅ Processed and saved HINDUNILVR_15m.csv
# ❌ Error processing HINDUNILVR_1h.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved HINDUNILVR_1m.csv
# ❌ Error processing HINDUNILVR_30m.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved HINDUNILVR_3m.csv
# ✅ Processed and saved HINDUNILVR_5m.csv
# ✅ Processed and saved ICICIBANK_10m.csv
# ✅ Processed and saved ICICIBANK_15m.csv
# ❌ Error processing ICICIBANK_1h.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved ICICIBANK_1m.csv
# ❌ Error processing ICICIBANK_30m.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved ICICIBANK_3m.csv
# ✅ Processed and saved ICICIBANK_5m.csv
# ✅ Processed and saved INDUSINDBK_10m.csv
# ✅ Processed and saved INDUSINDBK_15m.csv
# ❌ Error processing INDUSINDBK_1h.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved INDUSINDBK_1m.csv
# ❌ Error processing INDUSINDBK_30m.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved INDUSINDBK_3m.csv
# ✅ Processed and saved INDUSINDBK_5m.csv
# ✅ Processed and saved INFY_10m.csv
# ✅ Processed and saved INFY_15m.csv
# ❌ Error processing INFY_1h.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved INFY_1m.csv
# ❌ Error processing INFY_30m.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved INFY_3m.csv
# ✅ Processed and saved INFY_5m.csv
# ✅ Processed and saved ITC_10m.csv
# ✅ Processed and saved ITC_15m.csv
# ❌ Error processing ITC_1h.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved ITC_1m.csv
# ❌ Error processing ITC_30m.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved ITC_3m.csv
# ✅ Processed and saved ITC_5m.csv
# ✅ Processed and saved JIOFIN_10m.csv
# ✅ Processed and saved JIOFIN_15m.csv
# ❌ Error processing JIOFIN_1h.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved JIOFIN_1m.csv
# ❌ Error processing JIOFIN_30m.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved JIOFIN_3m.csv
# ✅ Processed and saved JIOFIN_5m.csv
# ✅ Processed and saved JSWSTEEL_10m.csv
# ✅ Processed and saved JSWSTEEL_15m.csv
# ❌ Error processing JSWSTEEL_1h.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved JSWSTEEL_1m.csv
# ❌ Error processing JSWSTEEL_30m.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved JSWSTEEL_3m.csv
# ✅ Processed and saved JSWSTEEL_5m.csv
# ✅ Processed and saved KOTAKBANK_10m.csv
# ✅ Processed and saved KOTAKBANK_15m.csv
# ❌ Error processing KOTAKBANK_1h.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved KOTAKBANK_1m.csv
# ❌ Error processing KOTAKBANK_30m.csv: index 14 is out of bounds for axis 0 with size 12
# ✅ Processed and saved KOTAKBANK_3m.csv
# ✅ Processed and saved KOTAKBANK_5m.csv
# ✅ Processed and saved LT_10m.csv
# ✅ Processed and saved LT_15m.csv
# ❌ Error processing LT_1h.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved LT_1m.csv
# ❌ Error processing LT_30m.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved LT_3m.csv
# ✅ Processed and saved LT_5m.csv
# ✅ Processed and saved M&M_10m.csv
# ✅ Processed and saved M&M_15m.csv
# ❌ Error processing M&M_1h.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved M&M_1m.csv
# ❌ Error processing M&M_30m.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved M&M_3m.csv
# ✅ Processed and saved M&M_5m.csv
# ✅ Processed and saved MARUTI_10m.csv
# ✅ Processed and saved MARUTI_15m.csv
# ❌ Error processing MARUTI_1h.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved MARUTI_1m.csv
# ❌ Error processing MARUTI_30m.csv: index 14 is out of bounds for axis 0 with size 12
# ✅ Processed and saved MARUTI_3m.csv
# ✅ Processed and saved MARUTI_5m.csv
# ✅ Processed and saved NESTLEIND_10m.csv
# ✅ Processed and saved NESTLEIND_15m.csv
# ❌ Error processing NESTLEIND_1h.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved NESTLEIND_1m.csv
# ❌ Error processing NESTLEIND_30m.csv: index 14 is out of bounds for axis 0 with size 12
# ✅ Processed and saved NESTLEIND_3m.csv
# ✅ Processed and saved NESTLEIND_5m.csv
# ✅ Processed and saved NTPC_10m.csv
# ✅ Processed and saved NTPC_15m.csv
# ❌ Error processing NTPC_1h.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved NTPC_1m.csv
# ❌ Error processing NTPC_30m.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved NTPC_3m.csv
# ✅ Processed and saved NTPC_5m.csv
# ✅ Processed and saved ONGC_10m.csv
# ✅ Processed and saved ONGC_15m.csv
# ❌ Error processing ONGC_1h.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved ONGC_1m.csv
# ❌ Error processing ONGC_30m.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved ONGC_3m.csv
# ✅ Processed and saved ONGC_5m.csv
# ✅ Processed and saved POWERGRID_10m.csv
# ✅ Processed and saved POWERGRID_15m.csv
# ❌ Error processing POWERGRID_1h.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved POWERGRID_1m.csv
# ❌ Error processing POWERGRID_30m.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved POWERGRID_3m.csv
# ✅ Processed and saved POWERGRID_5m.csv
# ✅ Processed and saved RELIANCE_10m.csv
# ✅ Processed and saved RELIANCE_15m.csv
# ❌ Error processing RELIANCE_1h.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved RELIANCE_1m.csv
# ❌ Error processing RELIANCE_30m.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved RELIANCE_3m.csv
# ✅ Processed and saved RELIANCE_5m.csv
# ✅ Processed and saved SBILIFE_10m.csv
# ✅ Processed and saved SBILIFE_15m.csv
# ❌ Error processing SBILIFE_1h.csv: index 14 is out of bounds for axis 0 with size 12
# ✅ Processed and saved SBILIFE_1m.csv
# ❌ Error processing SBILIFE_30m.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved SBILIFE_3m.csv
# ✅ Processed and saved SBILIFE_5m.csv
# ✅ Processed and saved SBIN_10m.csv
# ✅ Processed and saved SBIN_15m.csv
# ❌ Error processing SBIN_1h.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved SBIN_1m.csv
# ❌ Error processing SBIN_30m.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved SBIN_3m.csv
# ✅ Processed and saved SBIN_5m.csv
# ✅ Processed and saved SHRIRAMFIN_10m.csv
# ✅ Processed and saved SHRIRAMFIN_15m.csv
# ❌ Error processing SHRIRAMFIN_1h.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved SHRIRAMFIN_1m.csv
# ❌ Error processing SHRIRAMFIN_30m.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved SHRIRAMFIN_3m.csv
# ✅ Processed and saved SHRIRAMFIN_5m.csv
# ✅ Processed and saved SUNPHARMA_10m.csv
# ✅ Processed and saved SUNPHARMA_15m.csv
# ❌ Error processing SUNPHARMA_1h.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved SUNPHARMA_1m.csv
# ❌ Error processing SUNPHARMA_30m.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved SUNPHARMA_3m.csv
# ✅ Processed and saved SUNPHARMA_5m.csv
# ✅ Processed and saved TATACONSUM_10m.csv
# ✅ Processed and saved TATACONSUM_15m.csv
# ❌ Error processing TATACONSUM_1h.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved TATACONSUM_1m.csv
# ❌ Error processing TATACONSUM_30m.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved TATACONSUM_3m.csv
# ✅ Processed and saved TATACONSUM_5m.csv
# ✅ Processed and saved TATAMOTORS_10m.csv
# ✅ Processed and saved TATAMOTORS_15m.csv
# ❌ Error processing TATAMOTORS_1h.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved TATAMOTORS_1m.csv
# ❌ Error processing TATAMOTORS_30m.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved TATAMOTORS_3m.csv
# ✅ Processed and saved TATAMOTORS_5m.csv
# ✅ Processed and saved TATASTEEL_10m.csv
# ✅ Processed and saved TATASTEEL_15m.csv
# ❌ Error processing TATASTEEL_1h.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved TATASTEEL_1m.csv
# ❌ Error processing TATASTEEL_30m.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved TATASTEEL_3m.csv
# ✅ Processed and saved TATASTEEL_5m.csv
# ✅ Processed and saved TCS_10m.csv
# ✅ Processed and saved TCS_15m.csv
# ❌ Error processing TCS_1h.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved TCS_1m.csv
# ❌ Error processing TCS_30m.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved TCS_3m.csv
# ✅ Processed and saved TCS_5m.csv
# ✅ Processed and saved TECHM_10m.csv
# ✅ Processed and saved TECHM_15m.csv
# ❌ Error processing TECHM_1h.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved TECHM_1m.csv
# ❌ Error processing TECHM_30m.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved TECHM_3m.csv
# ✅ Processed and saved TECHM_5m.csv
# ✅ Processed and saved TITAN_10m.csv
# ✅ Processed and saved TITAN_15m.csv
# ❌ Error processing TITAN_1h.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved TITAN_1m.csv
# ❌ Error processing TITAN_30m.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved TITAN_3m.csv
# ✅ Processed and saved TITAN_5m.csv
# ✅ Processed and saved TRENT_10m.csv
# ✅ Processed and saved TRENT_15m.csv
# ❌ Error processing TRENT_1h.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved TRENT_1m.csv
# ❌ Error processing TRENT_30m.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved TRENT_3m.csv
# ✅ Processed and saved TRENT_5m.csv
# ✅ Processed and saved ULTRACEMCO_10m.csv
# ✅ Processed and saved ULTRACEMCO_15m.csv
# ❌ Error processing ULTRACEMCO_1h.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved ULTRACEMCO_1m.csv
# ❌ Error processing ULTRACEMCO_30m.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved ULTRACEMCO_3m.csv
# ✅ Processed and saved ULTRACEMCO_5m.csv
# ✅ Processed and saved WIPRO_10m.csv
# ✅ Processed and saved WIPRO_15m.csv
# ❌ Error processing WIPRO_1h.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved WIPRO_1m.csv
# ❌ Error processing WIPRO_30m.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved WIPRO_3m.csv
# ✅ Processed and saved WIPRO_5m.csv
# ✅ Processed and saved ZOMATO_10m.csv
# ✅ Processed and saved ZOMATO_15m.csv
# ❌ Error processing ZOMATO_1h.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved ZOMATO_1m.csv
# ❌ Error processing ZOMATO_30m.csv: index 14 is out of bounds for axis 0 with size 11
# ✅ Processed and saved ZOMATO_3m.csv
# ✅ Processed and saved ZOMATO_5m.csv
