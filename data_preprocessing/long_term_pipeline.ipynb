# %%
# import os
# import sys
# import pandas as pd

# sys.path.append(os.path.abspath('./'))

# from utils import add_technical_indicators, calculate_return

# def create_long_term_windows(input_folder, output_folder, window_days=252, prediction_days=252):
#     os.makedirs(output_folder, exist_ok=True)
#     all_files = [f for f in os.listdir(input_folder) if f.endswith(".csv")]

#     for file in all_files:
#         symbol = file.replace("_data.csv", "")
#         df = pd.read_csv(os.path.join(input_folder, file), parse_dates=["Date"])
#         df = df.sort_values("Date").reset_index(drop=True)

#         windows = []  # list to hold all windows

#         for start in range(len(df) - window_days - prediction_days):
#             x_window = df.iloc[start:start + window_days].copy()
#             future_window = df.iloc[start + window_days:start + window_days + prediction_days]

#             if len(future_window) < prediction_days:
#                 continue

#             start_price = future_window.iloc[0]["Close"]
#             end_price = future_window.iloc[-1]["Close"]
#             label = calculate_return(start_price, end_price)

#             x_window_ta = add_technical_indicators(x_window)
#             x_window_ta["TargetReturn"] = label
#             x_window_ta["Symbol"] = symbol
#             x_window_ta["WindowID"] = start

        #     # Add a marker for each row so we can split back if needed
        #     x_window_ta["RowInWindow"] = list(range(len(x_window_ta)))

        #     windows.append(x_window_ta)

        # if windows:
        #     all_data = pd.concat(windows, ignore_index=True)
        #     output_file = os.path.join(output_folder, f"{symbol}_long_term_windows.csv")
        #     all_data.to_csv(output_file, index=False)
        #     print(f"✅ Processed {symbol}: {len(windows)} windows saved in one file.")
        # else:
        #     print(f"⚠️ Skipped {symbol}: No valid windows.")


import os
import pandas as pd
from utils import add_technical_indicators

def load_processed_symbols(log_path):
    if os.path.exists(log_path):
        with open(log_path, "r") as f:
            return set(line.strip() for line in f.readlines())
    return set()

def log_processed_symbol(log_path, symbol):
    with open(log_path, "a") as f:
        f.write(symbol + "\n")

def create_long_term_windows(input_folder, output_folder, window_days=252, prediction_days=252):
    os.makedirs(output_folder, exist_ok=True)
    
    # Log file path
    log_file_path = os.path.join(output_folder, "processed_files.txt")
    processed_symbols = load_processed_symbols(log_file_path)

    all_files = [f for f in os.listdir(input_folder) if f.endswith(".csv")]

    for file in all_files:
        symbol = file.replace("_data.csv", "")
        if symbol in processed_symbols:
            print(f"⏩ Skipping {symbol} (already processed)")
            continue

        df = pd.read_csv(os.path.join(input_folder, file), parse_dates=["Date"])
        df = df.sort_values("Date").reset_index(drop=True)
        df_ta = add_technical_indicators(df.copy())  # Compute indicators once ✅

        windows = []

        for start in range(len(df_ta) - window_days - prediction_days):
            x_window = df_ta.iloc[start:start + window_days].copy()
            future_window = df_ta.iloc[start + window_days:start + window_days + prediction_days]

            if len(future_window) < prediction_days:
                continue

            start_price = future_window.iloc[0]["Close"]
            end_price = future_window.iloc[-1]["Close"]
            label = (end_price - start_price) / start_price

            x_window["TargetReturn"] = label
            x_window["Symbol"] = symbol
            x_window["WindowID"] = start
            x_window["RowInWindow"] = list(range(len(x_window)))

            windows.append(x_window)

        if windows:
            all_data = pd.concat(windows, ignore_index=True)
            output_file = os.path.join(output_folder, f"{symbol}_long_term_windows.csv")
            all_data.to_csv(output_file, index=False)
            log_processed_symbol(log_file_path, symbol)
            print(f"✅ Processed {symbol}: {len(windows)} windows.")
        else:
            print(f"⚠️ Skipped {symbol}: No valid windows.")

# %%
create_long_term_windows(
    input_folder="../data/stock_data",
    output_folder="../data/long_term_features"
)
# Out:
# ⏩ Skipping 360ONE.NS (already processed)
# ⚠️ Skipped AADHARHFC.NS: No valid windows.
# ⏩ Skipping AAVAS.NS (already processed)
# ⏩ Skipping ABBOTINDIA.NS (already processed)
# ⏩ Skipping ABCAPITAL.NS (already processed)
# ⏩ Skipping ABSLAMC.NS (already processed)
# ⏩ Skipping ACC.NS (already processed)
# ⚠️ Skipped ACMESOLAR.NS: No valid windows.
# ⚠️ Skipped ADANIENSOL.NS: No valid windows.
# ⏩ Skipping ADANIENT.NS (already processed)
# ⏩ Skipping ADANIGREEN.NS (already processed)
# ⏩ Skipping ADANIPOWER.NS (already processed)
# ⚠️ Skipped AEGISLOG.NS: No valid windows.
# ⏩ Skipping AFFLE.NS (already processed)
# ⚠️ Skipped AIIL.NS: No valid windows.
# ⏩ Skipping AJANTPHARM.NS (already processed)
# ⚠️ Skipped AKUMS.NS: No valid windows.
# ⚠️ Skipped ALIVUS.NS: No valid windows.
# ⏩ Skipping ALKEM.NS (already processed)
# ⏩ Skipping ALOKINDS.NS (already processed)
# ⏩ Skipping AMBER.NS (already processed)
# ⏩ Skipping AMBUJACEM.NS (already processed)
# ⏩ Skipping ANANDRATHI.NS (already processed)
# ⏩ Skipping ANGELONE.NS (already processed)
# ⏩ Skipping APLLTD.NS (already processed)
# ⏩ Skipping APOLLOHOSP.NS (already processed)
# ⏩ Skipping APOLLOTYRE.NS (already processed)
# ⏩ Skipping APTUS.NS (already processed)
# ⚠️ Skipped ARE&M.NS: No valid windows.
# ⏩ Skipping ASAHIINDIA.NS (already processed)
# ⏩ Skipping ASIANPAINT.NS (already processed)
# ⏩ Skipping ASTERDM.NS (already processed)
# ⏩ Skipping ASTRAZEN.NS (already processed)
# ⏩ Skipping ATGL.NS (already processed)
# ⏩ Skipping AUBANK.NS (already processed)
# ⏩ Skipping AUROPHARMA.NS (already processed)
# ⏩ Skipping AXISBANK.NS (already processed)
# ⏩ Skipping BAJAJ-AUTO.NS (already processed)
# ⏩ Skipping BAJAJFINSV.NS (already processed)
# ⚠️ Skipped BAJAJHFL.NS: No valid windows.
# ⏩ Skipping BAJAJHLDNG.NS (already processed)
# ⏩ Skipping BAJFINANCE.NS (already processed)
# ⏩ Skipping BALKRISIND.NS (already processed)
# ⏩ Skipping BANDHANBNK.NS (already processed)
# ⏩ Skipping BANKBARODA.NS (already processed)
# ⏩ Skipping BANKINDIA.NS (already processed)
# ⏩ Skipping BATAINDIA.NS (already processed)
# ⏩ Skipping BERGEPAINT.NS (already processed)
# ⏩ Skipping BHARATFORG.NS (already processed)
# ⏩ Skipping BIOCON.NS (already processed)
# ⏩ Skipping BIRLACORPN.NS (already processed)
# ⏩ Skipping BLUESTARCO.NS (already processed)
# ⏩ Skipping BOSCHLTD.NS (already processed)
# ⏩ Skipping BPCL.NS (already processed)
# ⏩ Skipping BSE.NS (already processed)
# ⏩ Skipping BSOFT.NS (already processed)
# ⏩ Skipping CAMPUS.NS (already processed)
# ⏩ Skipping CAMS.NS (already processed)
# ⏩ Skipping CANBK.NS (already processed)
# ⏩ Skipping CANFINHOME.NS (already processed)
# ⏩ Skipping CAPLIPOINT.NS (already processed)
# ⏩ Skipping CASTROLIND.NS (already processed)
# ⏩ Skipping CDSL.NS (already processed)
# ⏩ Skipping CEATLTD.NS (already processed)
# ⚠️ Skipped CELLO.NS: No valid windows.
# ⏩ Skipping CENTRALBK.NS (already processed)
# ⏩ Skipping CENTURYPLY.NS (already processed)
# ⏩ Skipping CERA.NS (already processed)
# ⏩ Skipping CESC.NS (already processed)
# ⏩ Skipping CGCL.NS (already processed)
# ⏩ Skipping CHENNPETRO.NS (already processed)
# ⏩ Skipping CHOLAFIN.NS (already processed)
# ⏩ Skipping CHOLAHLDNG.NS (already processed)
# ⏩ Skipping CIEINDIA.NS (already processed)
# ⏩ Skipping CIPLA.NS (already processed)
# ⏩ Skipping COALINDIA.NS (already processed)
# ⏩ Skipping COFORGE.NS (already processed)
# ⚠️ Skipped CONCORDBIO.NS: No valid windows.
# ⏩ Skipping CRAFTSMAN.NS (already processed)
# ⏩ Skipping CREDITACC.NS (already processed)
# ⏩ Skipping CRISIL.NS (already processed)
# ⏩ Skipping CROMPTON.NS (already processed)
# ⏩ Skipping CUB.NS (already processed)
# ⏩ Skipping CYIENT.NS (already processed)
# ⏩ Skipping DALBHARAT.NS (already processed)
# ⏩ Skipping DIVISLAB.NS (already processed)
# ⏩ Skipping DIXON.NS (already processed)
# ⏩ Skipping DRREDDY.NS (already processed)
# ⏩ Skipping EICHERMOT.NS (already processed)
# ⚠️ Skipped EMCURE.NS: No valid windows.
# ⏩ Skipping ENDURANCE.NS (already processed)
# ⏩ Skipping EQUITASBNK.NS (already processed)
# ⏩ Skipping ERIS.NS (already processed)
# ⏩ Skipping EXIDEIND.NS (already processed)
# ⏩ Skipping FORTIS.NS (already processed)
# ⏩ Skipping GAIL.NS (already processed)
# ⏩ Skipping GLAND.NS (already processed)
# ⏩ Skipping GLAXO.NS (already processed)
# ⏩ Skipping GLENMARK.NS (already processed)
# ⏩ Skipping GMDCLTD.NS (already processed)
# ⏩ Skipping GRANULES.NS (already processed)
# ⏩ Skipping GRASIM.NS (already processed)
# ⏩ Skipping GRAVITA.NS (already processed)
# ⏩ Skipping GSPL.NS (already processed)
# ⏩ Skipping GUJGASLTD.NS (already processed)
# ⏩ Skipping HAPPSTMNDS.NS (already processed)
# ⏩ Skipping HAVELLS.NS (already processed)
# ⚠️ Skipped HBLENGINE.NS: No valid windows.
# ⏩ Skipping HCLTECH.NS (already processed)
# ⏩ Skipping HEROMOTOCO.NS (already processed)
# ⏩ Skipping HINDALCO.NS (already processed)
# ⏩ Skipping HINDCOPPER.NS (already processed)
# ⏩ Skipping HINDPETRO.NS (already processed)
# ⏩ Skipping HINDZINC.NS (already processed)
# ⚠️ Skipped HYUNDAI.NS: No valid windows.
# ⏩ Skipping IGL.NS (already processed)
# ⚠️ Skipped IKS.NS: No valid windows.
# ⚠️ Skipped INDGN.NS: No valid windows.
# ⏩ Skipping INDIACEM.NS (already processed)
# ⏩ Skipping INFY.NS (already processed)
# ⏩ Skipping INTELLECT.NS (already processed)
# ⏩ Skipping IOC.NS (already processed)
# ⏩ Skipping JBMA.NS (already processed)
# ⏩ Skipping JINDALSTEL.NS (already processed)
# ⏩ Skipping JKCEMENT.NS (already processed)
# ⏩ Skipping JKLAKSHMI.NS (already processed)
# ⏩ Skipping JKTYRE.NS (already processed)
# ⏩ Skipping JPPOWER.NS (already processed)
# ⏩ Skipping JSL.NS (already processed)
# ⏩ Skipping JSWENERGY.NS (already processed)
# ⏩ Skipping JSWSTEEL.NS (already processed)
# ⏩ Skipping KAJARIACER.NS (already processed)
# ⏩ Skipping KALYANKJIL.NS (already processed)
# ⏩ Skipping KANSAINER.NS (already processed)
# ⏩ Skipping KPITTECH.NS (already processed)
# ⏩ Skipping KPRMILL.NS (already processed)
# ⏩ Skipping LALPATHLAB.NS (already processed)
# ⏩ Skipping LATENTVIEW.NS (already processed)
# ⚠️ Skipped LLOYDSME.NS: No valid windows.
# ⏩ Skipping LTIM.NS (already processed)
# ⏩ Skipping LTTS.NS (already processed)
# ⏩ Skipping M&M.NS (already processed)
# ⏩ Skipping MAHABANK.NS (already processed)
# ⏩ Skipping MAPMYINDIA.NS (already processed)
# ⏩ Skipping MARUTI.NS (already processed)
# ⏩ Skipping MASTEK.NS (already processed)
# ⏩ Skipping MEDANTA.NS (already processed)
# ⏩ Skipping MGL.NS (already processed)
# ⏩ Skipping MINDACORP.NS (already processed)
# ⏩ Skipping MPHASIS.NS (already processed)
# ⏩ Skipping MRF.NS (already processed)
# ⏩ Skipping MRPL.NS (already processed)
# ⏩ Skipping NATIONALUM.NS (already processed)
# ⏩ Skipping NAVA.NS (already processed)
# ⚠️ Skipped NETWEB.NS: No valid windows.
# ⏩ Skipping NEWGEN.NS (already processed)
# ⏩ Skipping NHPC.NS (already processed)
# ⏩ Skipping NLCINDIA.NS (already processed)
# ⏩ Skipping NMDC.NS (already processed)
# ⏩ Skipping NSLNISP.NS (already processed)
# ⏩ Skipping NTPC.NS (already processed)
# ⚠️ Skipped NTPCGREEN.NS: No valid windows.
# ⏩ Skipping NUVOCO.NS (already processed)
# ⏩ Skipping OFSS.NS (already processed)
# ⏩ Skipping OIL.NS (already processed)
# ⏩ Skipping ONGC.NS (already processed)
# ⏩ Skipping PAGEIND.NS (already processed)
# ⏩ Skipping PERSISTENT.NS (already processed)
# ⏩ Skipping PETRONET.NS (already processed)
# ⏩ Skipping PGEL.NS (already processed)
# ⏩ Skipping POWERGRID.NS (already processed)
# ⏩ Skipping RAMCOCEM.NS (already processed)
# ⚠️ Skipped RAYMONDLSL.NS: No valid windows.
# ⏩ Skipping RELIANCE.NS (already processed)
# ⏩ Skipping RPOWER.NS (already processed)
# ⚠️ Skipped SAGILITY.NS: No valid windows.
# ⏩ Skipping SAIL.NS (already processed)
# ⏩ Skipping SARDAEN.NS (already processed)
# ⏩ Skipping SHREECEM.NS (already processed)
# ⏩ Skipping SJVN.NS (already processed)
# ⏩ Skipping SONATSOFTW.NS (already processed)
# ⏩ Skipping TANLA.NS (already processed)
# ⏩ Skipping TATAELXSI.NS (already processed)
# ⏩ Skipping TATAPOWER.NS (already processed)
# ⏩ Skipping TATASTEEL.NS (already processed)
# ⚠️ Skipped TATATECH.NS: No valid windows.
# ⏩ Skipping TCS.NS (already processed)
# ⏩ Skipping TECHM.NS (already processed)
# ⏩ Skipping TORNTPOWER.NS (already processed)
# ⏩ Skipping TRIDENT.NS (already processed)
# ⏩ Skipping ULTRACEMCO.NS (already processed)
# ⏩ Skipping VEDL.NS (already processed)
# ⏩ Skipping VTL.NS (already processed)
# ⏩ Skipping WELSPUNLIV.NS (already processed)
